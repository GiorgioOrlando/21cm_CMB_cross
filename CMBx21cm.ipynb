# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,AutoMinorLocator,LogLocator,MaxNLocator)
from scipy.interpolate import InterpolatedUnivariateSpline as interpolate
from scipy.interpolate import interp1d as interp1d
from scipy.misc import derivative
import inspect
from scipy.optimize import curve_fit as fit
import scipy.integrate as scint
from scipy.special import spherical_jn as jn
from tqdm.notebook import trange, tqdm
import time
import pywigxjpf as wig
from scipy.linalg._matfuncs_sqrtm_triu import within_block_loop
import mpmath
from scipy import integrate
from joblib import Parallel, delayed

from tqdm import tqdm

import sympy as sy
import camb
from ipykernel import kernelapp as app


#plotParameters();
mpl.rcParams.update(mpl.rcParamsDefault)
plt.rcParams['mathtext.fontset'] = 'cm'

# %%
# definition of Wigner symbols 3j-6j-9j.
# Numerically expensive for lmax>20000. Need more than 100 GB to handle lmax=100000

wig.wig_table_init(40002,3)
wig.wig_temp_init(40002)

def w3j(l1,l2,l3,m1,m2,m3):
    return wig.wig3jj(2*l1, 2*l2, 2*l3, 2*m1, 2*m2, 2*m3)

def w6j(l1,l2,l3,l4,l5,l6):
    return wig.wig6jj(2*l1, 2*l2, 2*l3, 2*l4, 2*l5, 2*l6)

def w9j(l1,l2,l3,l4,l5,l6,l7,l8,l9):
    return wig.wig9jj(2*l1, 2*l2, 2*l3, 2*l4, 2*l5, 2*l6, 2*l7, 2*l8, 2*l9)

# %%
# remove the previous Wigner symbols (to be used at the end)

wig.wig_table_free()
wig.wig_temp_free()

# %%
# low-memory definition of Wigner symbol 3j, valid when m1 = m2 = m3 = 0

def wigner3jm0(l1,l2,l3):
    if l3 >l1+l2 or l3 < np.abs(l1-l2) or (l1+l2+l3) % 2== 1:
        value = 0.
        return value
    else:
        factor1 = mpmath.factorial(l1/2+l2/2+l3/2)
        factor2 = mpmath.factorial(-l1/2+l2/2+l3/2)
        factor3 = mpmath.factorial(l1/2-l2/2+l3/2)
        factor4 = mpmath.factorial(l1/2+l2/2-l3/2)
    
        sq1 = mpmath.sqrt(mpmath.factorial(-l1+l2+l3))
        sq2 = mpmath.sqrt(mpmath.factorial(l1-l2+l3))
        sq3 = mpmath.sqrt(mpmath.factorial(l1+l2-l3))
    
        sq4 = mpmath.sqrt(mpmath.factorial(l1+l2+l3+1))
    
        value = (-1)**(-l1/2-l2/2-l3/2)*factor1*sq1*sq2*sq3/factor2/factor3/factor4/sq4
    
        return float(value)

def wigner3jm02(l1,l2,l3):
    return w3j(l1,l2,l3,0,0,0)

# %%
# check timing
# %timeit wigner3jm02(10000,10000,2)
# Out:
# 36.7 µs ± 163 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# check timing
# %timeit wigner3jm0(50000,50000,2)
# Out:
# 104 µs ± 20.4 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# # IMPORT CMB TRANSFER FUNCTIONS AND POWER SPECTRA

# %%
#l, TT, EE, BB, TE
lcmb2,tcmb2,ecmb2,bcmb2,tecmb2 = np.loadtxt('external_data/CMBpower0.01.dat', unpack = True)
lcmb3,tcmb3,ecmb3,bcmb3,tecmb3 = np.loadtxt('external_data/CMBpower0.001.dat', unpack = True)

cmbtrt = np.genfromtxt('external_data/CMB_transfer_tensor.dat')
llist = np.unique(cmbtrt[:,0]).astype(np.int64)
cmbtrt = cmbtrt.reshape(len(llist),len(cmbtrt)//len(llist),5)

cmbtrs = np.genfromtxt('external_data/CMB_transfer_scalar.dat')
llist = np.unique(cmbtrs[:,0]).astype(np.int64)
cmbtrs = cmbtrs.reshape(len(llist),len(cmbtrs)//len(llist),5)

# %%
#functions calling CMB PS with correct normalization, in the end we take r = 0.01, nothing really changes

def cTT(i,r):
    l=llist[i]
    if r == 0.01:
        val = tcmb2[i]/(10**12*l*(l+1)/(2*np.pi)*2.7255**2) 
    elif r == 0.001:
        val = tcmb3[i]/(10**12*l*(l+1)/(2*np.pi)*2.7255**2)
    return val


def cEE(i,r):
    l=llist[i]
    if r == 0.01:
        val = ecmb2[i]/(10**12*l*(l+1)/(2*np.pi)*2.7255**2) 
    elif r == 0.001:
        val = ecmb3[i]/(10**12*l*(l+1)/(2*np.pi)*2.7255**2)
    return val


def cET(i,r):
    l=llist[i]
    if r == 0.01:
        val = tecmb2[i]/(10**12*l*(l+1)/(2*np.pi)*2.7255**2) 
    elif r == 0.001:
        val = tecmb3[i]/(10**12*l*(l+1)/(2*np.pi)*2.7255**2)
    return val

# collecting CMB spectra
cTTspectra = np.array([cTT(i,0.01) for i in range(len(llist))])
cEEspectra = np.array([cEE(i,0.01) for i in range(len(llist))])
cETspectra = np.array([cET(i,0.01) for i in range(len(llist))])

# %% [markdown]
# # LOAD 21-cm Baryon Transfer from CAMB, Same Cosmology

# %%
pars=camb.set_params(H0=67.32117, ombh2= 0.0223828, omch2= 0.1201075, tau =0.05430842,
                     As= 2.100549e-9, ns= 0.9660499)
#pars=camb.read_ini('planck_2018_acc.ini')

pars.Do21cm  =True

pars.Evolve_delta_xe =True # ionization fraction perturbations
pars.Evolve_baryon_cs  = True # accurate baryon perturbations
pars.WantCls =False
pars.SourceTerms.use_21cm_mK = False # Use dimensionless rather than mK units
redshifts=[30,50,100] # The red-shifts in use in the paper, can change if you want
pars.set_matter_power(kmax=1000., redshifts=redshifts)

# get baryon_etc-transfer functions
results= camb.get_results(pars)
trans = results.get_matter_transfer_data()
# Out:
# Note: redshifts have been re-sorted (earliest first)

# %%
# interpolation of baryonic transfer function, for the red-shifts selected
k = trans.transfer_data[0,:,0]*results.Params.h
mono30 = trans.transfer_data[2,:,2]
mono50 = trans.transfer_data[2,:,1]
mono100 = trans.transfer_data[2,:,0]


mono30f=interpolate(k,mono30*k**2,ext=0)

mono50f=interpolate(k,mono50*k**2,ext=0)

mono100f=interpolate(k,mono100*k**2,ext=0)

# %% [markdown]
# # DEFINE USEFUL FUNCTIONS

# %%
# Hubble parameter H(z)
def H(z):
    value = results.h_of_z(z)
    return value

# conformal time \eta(z)
def eta(z):
    value = results.conformal_time(z)
    return value

# co-moving distance r(z)
def r(z):
    integrand =  lambda x: 1/H(x)
    int = scint.quad(integrand,0,z)
    return int[0]

# compute co-moving distance at selected red-shifts and recomb
r30 = r(30)
r50 = r(50)
r100 = r(100)
r1100 = r(1100)

# scale factor a(z)
def a(z):
    value = 1/(1+z)
    return value

# get scalar PS
def scal_pow(k):
    As = 2.100549e-09
    ns = 0.9660499
    kpivot = 0.05
    pfactor = As*kpivot**(1.-ns)
    return pfactor*k**(ns-1.)

# dimensionless scalar PS
def scalarpower(q):
    value = 2*np.pi**2*scal_pow(q)/q**3
    return value

# 21-cm transfer from Munoz et. al. arXiv:1506.04152
def trans(qpar,l,r,z):
    if z==30:
        alpha = alp1r(r30)
        T = t21r(r30)
    elif z==50:
        alpha = alp1r(r50)
        T = t21r(r50)
    elif z==100:
        alpha = alp1r(r100)
        T = t21r(r100)
    value = (alpha + T*qpar**2/(qpar**2+l**2/r**2))
    return value

# Omega_m (specific for the cosmology of the paper)
Omegam = 0.0223828+0.1201075

# Window function 21-cm Fourier space
def Wq(qpar,z,dnu):
    deltaD = 17*np.sqrt((1+z)/10*0.15/Omegam)*dnu/2
    value = np.exp(-qpar**2*deltaD**2/2)
    return value


# radial direction resolution
def deltar(z,dnu):
    return np.sqrt((1+z)/10*0.15/Omegam)*(dnu/0.1)

# Window function 21-cm
def W(rmean,r,z,dnu):
    deltar = 17*np.sqrt((1+z)/10*0.15/Omegam)*dnu
    value = 1/deltar/np.sqrt(2*np.pi)*np.exp(-1/2*(r-rmean)**2/deltar**2)
    return value

# %%
# importing \alpha(z) and T(z) coefficients, from Floss et. al.:2201.08843

z,a11,a22,a33,a21,a31,a32 = np.loadtxt('external_data/alpha_coefficients_21.dat', unpack = True)
z21,T21 = np.loadtxt('external_data/T21.dat', unpack = True)


listz = np.arange(20,110)
listr = np.array([r(z) for z in listz])

alp1=interpolate(z,a11)
listalp1 = np.array([alp1(z) for z in listz])
alp1r = interpolate(listr,listalp1)

alp2=interpolate(z,a22)
listalp2 = np.array([alp2(z) for z in listz])
alp2r = interpolate(listr,listalp2)

alp3=interpolate(z,a21)
listalp3 = np.array([alp3(z) for z in listz])
alp3r = interpolate(listr,listalp3)


t21=interpolate(z21,T21)
listt21 = np.array([t21(z) for z in listz])
t21r = interpolate(listr,listt21)

# %%
# sampling of y for each red-shift, works for Delta_nu < 0.1 MHz. Need to modify 
# ymin and ymax for other frequency resolutions

y30 = np.linspace(r30-7,r30+7,15)
y50 = np.linspace(r50-7,r50+7,15)
y100 = np.linspace(r100-7,r100+7,15)

# sampling of y for each red-shift, works for Delta_nu = 1 MHz. Need to modify 
# ymin and ymax 

y301 = np.linspace(r30-100,r30+100,100)
y501 = np.linspace(r50-100,r50+100,100)
y1001 = np.linspace(r100-100,r100+100,100)

# %%
# c parameters describing secondaries 

c1 = 5/7
c2 = 1/2
c3 = 2/7

d0 = c1+c3/3
d2 = 2/3*c3

# %%
# secondaries coefficients

def I1c(z):
    value = alp1(z)*(alp2(z)*d0+alp3(z))
    return value

def I2c(z):
    value = alp1(z)*alp2(z)
    return value

# %%
# ratio between primordial and leading secondary coefficients

def estimation(z):
    value = alp1(z)/(alp2(z)*d0+alp3(z))
    return value

# %%
est = np.array([estimation(z) for z in listz])

# %%
# Plot of ratio between primordial and leading secondary coefficients
# +baryon transfer function

fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))



fig.subplots_adjust(wspace=0.3)



ax1.set_xlabel(r'$z$', fontsize=18)
ax2.set_xlabel(r'$k \, (Mpc^{-1})$', fontsize=18)


ax1.set_ylabel(r'$\alpha_{1}/(\alpha_{2} \, d_0 + \alpha_{3})$', fontsize=18)
ax2.set_ylabel(r'${\cal M}_b$', fontsize=18)


ax2.set_xlim(5e-5, 20)


#ax1.set_xscale('log')
ax2.set_xscale('log')

#ax1.set_yscale('log')
ax2.set_yscale('log')

ax1.plot(listz,estimation(listz), linewidth = 2.5,color = 'black', linestyle = '-', zorder = 10)


ax2.plot(k,mono30f(k), label = '$z=30$', color = 'royalblue', linewidth = 2.5, linestyle = '-', zorder = 10)
ax2.plot(k,mono50f(k), label = '$z=50$', color = 'darkorange', linewidth = 2.5, linestyle = '-', zorder = 10)
ax2.plot(k,mono100f(k), label = '$z=100$', color = 'darkgreen', linewidth = 2.5, linestyle = '-', zorder = 10)


ax2.legend(fontsize=15)#(loc='best', fontsize=20)


plt.savefig("plots/est.pdf", dpi=300, bbox_inches='tight')


plt.show()
plt.close()

# %% [markdown]
# # COMPUTATION OF PRIMORDIAL AND SECONDARY SIGNALS

# %%
# samplings

kk = cmbtrs[0,:,1]

jn_30 = np.array([jn(l3,np.outer(y30,kk)) for l3 in np.arange(0,20)])
jn_50 = np.array([jn(l3,np.outer(y50,kk)) for l3 in np.arange(0,20)])
jn_100 = np.array([jn(l3,np.outer(y100,kk)) for l3 in np.arange(0,20)])

scal_pow_kk = scal_pow(kk)
trans_30 = mono30f(kk)
trans_50 = mono50f(kk)
trans_100 = mono100f(kk)

# %%
# CMB k3-integral, <21-21-T>

# primordial I_1
def CMB_prim_I1_T(i,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn(l,np.outer(y,kk))*cmbtrs[i,:,2]*scal_pow_kk/kk
    inte = integrate.simps(integrand,x=kk)
    return inte

# primordial I_2
def CMB_prim_I2_T(i,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn(l,np.outer(y,kk))*cmbtrs[i,:,2]*kk**2
    inte = integrate.simps(integrand,x=kk)
    return inte

# secondary I_1 z=30
def CMB_sec_I1_30_T(i,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn(l,np.outer(y,kk))*cmbtrs[i,:,2]*scal_pow_kk*trans_30/kk
    inte = integrate.simps(integrand,x=kk)
    return inte

# secondary I_1 z=50
def CMB_sec_I1_50_T(i,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn(l,np.outer(y,kk))*cmbtrs[i,:,2]*scal_pow_kk*trans_50/kk
    inte = integrate.simps(integrand,x=kk)
    return inte

# secondary I_1 z=100
def CMB_sec_I1_100_T(i,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn(l,np.outer(y,kk))*cmbtrs[i,:,2]*scal_pow_kk*trans_100/kk
    inte = integrate.simps(integrand,x=kk)
    return inte

# secondary I_2 z=30
def CMB_sec_I2_30_T(i,L3,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn_30[L3]*cmbtrs[i,:,2]*scal_pow_kk*trans_30/kk**2
    inte = integrate.simps(integrand,x=kk)
    return inte

# secondary I_2 z=50
def CMB_sec_I2_50_T(i,L3,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn_50[L3]*cmbtrs[i,:,2]*scal_pow_kk*trans_50/kk**2
    inte = integrate.simps(integrand,x=kk)
    return inte

# secondary I_2 z=100
def CMB_sec_I2_100_T(i,L3,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn_100[L3]*cmbtrs[i,:,2]*scal_pow_kk*trans_100/kk**2
    inte = integrate.simps(integrand,x=kk)
    return inte



# secondary I_3 z=30
def CMB_sec_I3_30_T(i,L3,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn_30[L3]*cmbtrs[i,:,2]*scal_pow_kk*trans_30
    inte = integrate.simps(integrand,x=kk)
    return inte

# secondary I_3 z=50
def CMB_sec_I3_50_T(i,L3,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn_50[L3]*cmbtrs[i,:,2]*scal_pow_kk*trans_50
    inte = integrate.simps(integrand,x=kk)
    return inte

# secondary I_3 z=100
def CMB_sec_I3_100_T(i,L3,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn_100[L3]*cmbtrs[i,:,2]*scal_pow_kk*trans_100
    inte = integrate.simps(integrand,x=kk)
    return inte




# secondary I_4 z=30
def CMB_sec_I4_30_T(i,L3,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn_30[L3]*cmbtrs[i,:,2]*scal_pow_kk*trans_30/kk
    inte = integrate.simps(integrand,x=kk)
    return inte

# secondary I_4 z=50
def CMB_sec_I4_50_T(i,L3,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn_50[L3]*cmbtrs[i,:,2]*scal_pow_kk*trans_50/kk
    inte = integrate.simps(integrand,x=kk)
    return inte

# secondary I_4 z=100
def CMB_sec_I4_100_T(i,L3,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn_100[L3]*cmbtrs[i,:,2]*scal_pow_kk*trans_100/kk
    inte = integrate.simps(integrand,x=kk)
    return inte

# CMB T-mode PS, just to check normalizations are ok
def CMBspec(i):
    l=llist[i]
    ktr=np.zeros(int(len(cmbtrs[i][:])))
    ctr=np.zeros(int(len(cmbtrs[i][:])))
    for j in range(int(len(cmbtrs[i][:]))):
        ktr[j]=cmbtrs[i][j][1]
        ctr[j]=cmbtrs[i][j][2]
    T=interpolate(ktr,-ctr)
    integrand = lambda q: T(q)**2*scal_pow(q)/q
    qmin = ktr[0]
    qmax = ktr[-1]
    inte = scint.quad(integrand,qmin,qmax, epsabs=0.,epsrel=1e-4, limit = 10000000)[0]
    f =  4*np.pi
    value = f*inte
    return value

# %%
# CMB k3-integral, <21-21-E>

# in CAMB we need this additional factor for each E-mode
def factor2(l):
    return (l+2)*(l+1)*l*(l-1)

# primordial I_1

def CMB_prim_I1_E(i,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn(l,np.outer(y,kk))*np.sqrt(factor2(l))*cmbtrs[i,:,3]*scal_pow_kk/kk
    inte = integrate.simps(integrand,x=kk)
    return inte


# primordial I_2
def CMB_prim_I2_E(i,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn(l,np.outer(y,kk))*np.sqrt(factor2(l))*cmbtrs[i,:,3]*kk**2
    inte = integrate.simps(integrand,x=kk)
    return inte


# secondary I_1 z=30
def CMB_sec_I1_30_E(i,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn(l,np.outer(y,kk))*np.sqrt(factor2(l))*cmbtrs[i,:,3]*scal_pow_kk*trans_30/kk
    inte = integrate.simps(integrand,x=kk)
    return inte

# secondary I_1 z=50
def CMB_sec_I1_50_E(i,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn(l,np.outer(y,kk))*np.sqrt(factor2(l))*cmbtrs[i,:,3]*scal_pow_kk*trans_50/kk
    inte = integrate.simps(integrand,x=kk)
    return inte

# secondary I_1 z=100
def CMB_sec_I1_100_E(i,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn(l,np.outer(y,kk))*np.sqrt(factor2(l))*cmbtrs[i,:,3]*scal_pow_kk*trans_100/kk
    inte = integrate.simps(integrand,x=kk)
    return inte



# secondary I_2 z=30
def CMB_sec_I2_30_E(i,L3,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn_30[L3]*np.sqrt(factor2(l))*cmbtrs[i,:,3]*scal_pow_kk*trans_30/kk**2
    inte = integrate.simps(integrand,x=kk)
    return inte

# secondary I_2 z=50
def CMB_sec_I2_50_E(i,L3,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn_50[L3]*np.sqrt(factor2(l))*cmbtrs[i,:,3]*scal_pow_kk*trans_50/kk**2
    inte = integrate.simps(integrand,x=kk)
    return inte

# secondary I_2 z=100
def CMB_sec_I2_100_E(i,L3,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn_100[L3]*np.sqrt(factor2(l))*cmbtrs[i,:,3]*scal_pow_kk*trans_100/kk**2
    inte = integrate.simps(integrand,x=kk)
    return inte



# secondary I_3 z=30
def CMB_sec_I3_30_E(i,L3,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn_30[L3]*np.sqrt(factor2(l))*cmbtrs[i,:,3]*scal_pow_kk*trans_30
    inte = integrate.simps(integrand,x=kk)
    return inte

# secondary I_3 z=50
def CMB_sec_I3_50_E(i,L3,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn_50[L3]*np.sqrt(factor2(l))*cmbtrs[i,:,3]*scal_pow_kk*trans_50
    inte = integrate.simps(integrand,x=kk)
    return inte

# secondary I_3 z=100
def CMB_sec_I3_100_E(i,L3,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn_100[L3]*np.sqrt(factor2(l))*cmbtrs[i,:,3]*scal_pow_kk*trans_100
    inte = integrate.simps(integrand,x=kk)
    return inte




# secondary I_4 z=30
def CMB_sec_I4_30_E(i,L3,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn_30[L3]*np.sqrt(factor2(l))*cmbtrs[i,:,3]*scal_pow_kk*trans_30/kk
    inte = integrate.simps(integrand,x=kk)
    return inte

# secondary I_4 z=50
def CMB_sec_I4_50_E(i,L3,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn_50[L3]*np.sqrt(factor2(l))*cmbtrs[i,:,3]*scal_pow_kk*trans_50/kk
    inte = integrate.simps(integrand,x=kk)
    return inte

# secondary I_4 z=100
def CMB_sec_I4_100_E(i,L3,y):
    l=llist[i]
    kk = cmbtrs[i,:,1]
    integrand = - jn_100[L3]*np.sqrt(factor2(l))*cmbtrs[i,:,3]*scal_pow_kk*trans_100/kk
    inte = integrate.simps(integrand,x=kk)
    return inte

# %%
# R-terms as in the paper

# Eq. 39
R30T = np.array([CMB_prim_I1_T(i,r30)**2/cTT(i,0.01)  for i in np.arange(0,20)])
R50T = np.array([CMB_prim_I1_T(i,r50)**2/cTT(i,0.01)  for i in np.arange(0,20)])
R100T = np.array([CMB_prim_I1_T(i,r100)**2/cTT(i,0.01)  for i in np.arange(0,20)])

# Eq. 47
R30ET = np.array([CMB_prim_I1_T(i,r30)**2*cEE(i,0.01)/(cTT(i,0.01)*cEE(i,0.01)-cET(i,0.01)**2)+CMB_prim_I1_E(i,r30)**2*cTT(i,0.01)/(cTT(i,0.01)*cEE(i,0.01)-cET(i,0.01)**2)-2*CMB_prim_I1_T(i,r30)*CMB_prim_I1_E(i,r30)*cET(i,0.01)/(cTT(i,0.01)*cEE(i,0.01)-cET(i,0.01)**2)  for i in np.arange(0,20)])
R50ET = np.array([CMB_prim_I1_T(i,r50)**2*cEE(i,0.01)/(cTT(i,0.01)*cEE(i,0.01)-cET(i,0.01)**2)+CMB_prim_I1_E(i,r50)**2*cTT(i,0.01)/(cTT(i,0.01)*cEE(i,0.01)-cET(i,0.01)**2)-2*CMB_prim_I1_T(i,r50)*CMB_prim_I1_E(i,r50)*cET(i,0.01)/(cTT(i,0.01)*cEE(i,0.01)-cET(i,0.01)**2)  for i in np.arange(0,20)])
R100ET = np.array([CMB_prim_I1_T(i,r100)**2*cEE(i,0.01)/(cTT(i,0.01)*cEE(i,0.01)-cET(i,0.01)**2)+CMB_prim_I1_E(i,r100)**2*cTT(i,0.01)/(cTT(i,0.01)*cEE(i,0.01)-cET(i,0.01)**2)-2*CMB_prim_I1_T(i,r100)*CMB_prim_I1_E(i,r100)*cET(i,0.01)/(cTT(i,0.01)*cEE(i,0.01)-cET(i,0.01)**2)  for i in np.arange(0,20)])

# Eq. 58
R30Tsec = np.array([CMB_sec_I1_30_T(i,r30)*CMB_prim_I1_T(i,r30)/cTT(i,0.01)  for i in np.arange(0,20)])
R50Tsec = np.array([CMB_sec_I1_50_T(i,r50)*CMB_prim_I1_T(i,r50)/cTT(i,0.01)  for i in np.arange(0,20)])
R100Tsec = np.array([CMB_sec_I1_100_T(i,r100)*CMB_prim_I1_T(i,r100)/cTT(i,0.01)  for i in np.arange(0,20)])

# Eq. 59
R30ETsec = np.array([CMB_sec_I1_30_T(i,r30)*CMB_prim_I1_T(i,r30)*cEE(i,0.01)/(cTT(i,0.01)*cEE(i,0.01)-cET(i,0.01)**2)+CMB_sec_I1_30_E(i,r30)*CMB_prim_I1_E(i,r30)*cTT(i,0.01)/(cTT(i,0.01)*cEE(i,0.01)-cET(i,0.01)**2)-(CMB_sec_I1_30_T(i,r30)*CMB_prim_I1_E(i,r30)+CMB_prim_I1_T(i,r30)*CMB_sec_I1_30_E(i,r30))*cET(i,0.01)/(cTT(i,0.01)*cEE(i,0.01)-cET(i,0.01)**2)  for i in np.arange(0,20)])
R50ETsec = np.array([CMB_sec_I1_50_T(i,r50)*CMB_prim_I1_T(i,r50)*cEE(i,0.01)/(cTT(i,0.01)*cEE(i,0.01)-cET(i,0.01)**2)+CMB_sec_I1_50_E(i,r50)*CMB_prim_I1_E(i,r50)*cTT(i,0.01)/(cTT(i,0.01)*cEE(i,0.01)-cET(i,0.01)**2)-(CMB_sec_I1_50_T(i,r50)*CMB_prim_I1_E(i,r50)+CMB_prim_I1_T(i,r50)*CMB_sec_I1_50_E(i,r50))*cET(i,0.01)/(cTT(i,0.01)*cEE(i,0.01)-cET(i,0.01)**2)  for i in np.arange(0,20)])
R100ETsec = np.array([CMB_sec_I1_100_T(i,r100)*CMB_prim_I1_T(i,r100)*cEE(i,0.01)/(cTT(i,0.01)*cEE(i,0.01)-cET(i,0.01)**2)+CMB_sec_I1_100_E(i,r100)*CMB_prim_I1_E(i,r100)*cTT(i,0.01)/(cTT(i,0.01)*cEE(i,0.01)-cET(i,0.01)**2)-(CMB_sec_I1_100_T(i,r100)*CMB_prim_I1_E(i,r100)+CMB_prim_I1_T(i,r100)*CMB_sec_I1_100_E(i,r100))*cET(i,0.01)/(cTT(i,0.01)*cEE(i,0.01)-cET(i,0.01)**2)  for i in np.arange(0,20)])
    

# l for plots
lplot = np.array([i+2  for i in np.arange(0,20)])

# %%
# Plot of R^{T, prim}

plt.figsize=(6, 8)

plt.xticks([i+2  for i in np.arange(0,20) if (i+2)%2==0])

plt.xlabel(r'$\ell_3$', fontsize=18)


plt.ylabel(r'$R^{T, \rm prim}_{\ell_3}$', fontsize=18)



plt.yscale('log')



plt.plot(lplot,R30T,label = r'$z=30$', color = 'royalblue', linewidth = 2.5, linestyle = '-', zorder = 10)
plt.plot(lplot,R50T,label = r'$z=50$', color = 'darkorange',linewidth = 2.5, linestyle = '-', zorder = 10)
plt.plot(lplot,R100T,label = r'$z=100$', color = 'darkgreen',linewidth = 2.5, linestyle = '-', zorder = 10)

plt.grid(True, which='both',linestyle='--', alpha = 0.4)


plt.legend(loc='best', fontsize=15)#(loc='best', fontsize=20)

plt.savefig("plots/RTpriml3.pdf", dpi=300, bbox_inches='tight')


plt.show()
plt.close()

# %%
# Plot of R^{TE, prim}

plt.figsize=(6, 8)

plt.xlabel(r'$\ell_3$', fontsize=18)


plt.xticks([i+2  for i in np.arange(0,20) if (i+2)%2==0])


plt.ylabel(r'$R^{TE, \rm prim}_{\ell_3}$', fontsize=18)



plt.yscale('log')



plt.plot(lplot,R30ET,label = r'$z=30$', color = 'royalblue', linewidth = 2.5, linestyle = '-', zorder = 10)
plt.plot(lplot,R50ET,label = r'$z=50$', color = 'darkorange',linewidth = 2.5, linestyle = '-', zorder = 10)
plt.plot(lplot,R100ET,label = r'$z=100$', color = 'darkgreen',linewidth = 2.5, linestyle = '-', zorder = 10)

plt.grid(True, which='both',linestyle='--', alpha = 0.4)

plt.legend(loc='best', fontsize=15)#(loc='best', fontsize=20)

plt.savefig("plots/RTEpriml3.pdf", dpi=300, bbox_inches='tight')


plt.show()
plt.close()

# %%
# Plot of R^{T, sec} and R^{ET, sec}

fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))



plt.xticks([i+2  for i in np.arange(0,20) if (i+2)%2==0])

fig.subplots_adjust(hspace=0.7)
fig.subplots_adjust(wspace=0.2)


ax1.set_title(r'$T$ only', fontsize=18)
ax2.set_title(r'$T+E$', fontsize=18)


ax1.set_xlabel(r'$\ell_3$', fontsize=18)
ax2.set_xlabel(r'$\ell_3$', fontsize=18)




ax1.set_xlim(1.5,11.5)
ax2.set_xlim(1.5,11.5)


ax1.set_ylabel(r'$R^{\rm prim \times sec}_{\ell_3}$', fontsize=18)



ax1.set_yscale('log')
ax2.set_yscale('log')



ax1.plot(lplot,R30Tsec, label = r'$z=30$', color = 'royalblue', linewidth = 2, linestyle = '-', zorder = 10)
ax1.plot(lplot,R50Tsec, label = r'$z=50$', color = 'darkorange', linewidth = 2, linestyle = '-', zorder = 10)
ax1.plot(lplot,R100Tsec, label = r'$z=100$', color = 'darkgreen', linewidth = 2, linestyle = '-', zorder = 10)

ax2.plot(lplot,R30ETsec, label = r'$z=30$', color = 'royalblue', linewidth = 2, linestyle = '-', zorder = 10)
ax2.plot(lplot,R50ETsec, label = r'$z=50$', color = 'darkorange', linewidth = 2, linestyle = '-', zorder = 10)
ax2.plot(lplot,R100ETsec, label = r'$z=100$', color = 'darkgreen', linewidth = 2, linestyle = '-', zorder = 10)


ax2.legend(bbox_to_anchor=(1.20, 0.85), loc='center', ncol = 1, borderaxespad=0., fontsize=18)#(loc='best', fontsize=20)



ax1.tick_params(axis='both', which='both', direction='in', top=True, right=True, labelsize=20)
ax1.grid(True, which='both',linestyle='--', alpha = 0.4)

ax2.tick_params(axis='both', which='both', direction='in', top=True, right=True, labelsize=20)
ax2.grid(True, which='both',linestyle='--', alpha = 0.4)

# plt.ylim([1e-13,7e1])

# ax1.set_ylim([1.4e-6,6.2e-6])
plt.savefig("plots/Rsecvsl3.pdf", dpi=300, bbox_inches='tight')
plt.show()

# %%
# l1-l2 sampling

llist2 = np.arange(10000,100001)

# l3 sampling (the same as Fisher forecast)

l3list = np.arange(2,12)
l3list_index = l3list -2

# %%
# Creating y-l3 samplings of k3-integrals

CMB_prim_I1_T_y30 = np.array([CMB_prim_I1_T(i, y30) for i in l3list_index])
CMB_prim_I1_T_y50 = np.array([CMB_prim_I1_T(i, y50) for i in l3list_index])
CMB_prim_I1_T_y100 = np.array([CMB_prim_I1_T(i, y100) for i in l3list_index])

CMB_prim_I2_T_y30 = np.array([CMB_prim_I2_T(i, y30) for i in l3list_index])
CMB_prim_I2_T_y50 = np.array([CMB_prim_I2_T(i, y50) for i in l3list_index])
CMB_prim_I2_T_y100 = np.array([CMB_prim_I2_T(i, y100) for i in l3list_index])

CMB_prim_I1_E_y30 = np.array([CMB_prim_I1_E(i, y30) for i in l3list_index])
CMB_prim_I1_E_y50 = np.array([CMB_prim_I1_E(i, y50) for i in l3list_index])
CMB_prim_I1_E_y100 = np.array([CMB_prim_I1_E(i, y100) for i in l3list_index])

CMB_prim_I2_E_y30 = np.array([CMB_prim_I2_E(i, y30) for i in l3list_index])
CMB_prim_I2_E_y50 = np.array([CMB_prim_I2_E(i, y50) for i in l3list_index])
CMB_prim_I2_E_y100 = np.array([CMB_prim_I2_E(i, y100) for i in l3list_index])

CMB_sec_I1_T_y30 = np.array([CMB_sec_I1_30_T(i, y30) for i in l3list_index])
CMB_sec_I1_T_y50 = np.array([CMB_sec_I1_50_T(i, y50) for i in l3list_index])
CMB_sec_I1_T_y100 = np.array([CMB_sec_I1_100_T(i, y100) for i in l3list_index])

CMB_sec_I1_E_y30 = np.array([CMB_sec_I1_30_E(i, y30) for i in l3list_index])
CMB_sec_I1_E_y50 = np.array([CMB_sec_I1_50_E(i, y50) for i in l3list_index])
CMB_sec_I1_E_y100 = np.array([CMB_sec_I1_100_E(i, y100) for i in l3list_index])


def CMB_sec_I2_T_y30(i,L3):
    value = CMB_sec_I2_30_T(i,L3, y30)
    return value

def CMB_sec_I2_T_y50(i,L3):
    value = CMB_sec_I2_50_T(i,L3, y50)
    return value

def CMB_sec_I2_T_y100(i,L3):
    value = CMB_sec_I2_100_T(i,L3, y100)
    return value


def CMB_sec_I2_E_y30(i,L3):
    value = CMB_sec_I2_30_E(i,L3, y30)
    return value

def CMB_sec_I2_E_y50(i,L3):
    value = CMB_sec_I2_50_E(i,L3, y50)
    return value

def CMB_sec_I2_E_y100(i,L3):
    value = CMB_sec_I2_100_E(i,L3, y100)
    return value


def CMB_sec_I3_T_y30(i,L3):
    value = CMB_sec_I3_30_T(i,L3, y30)
    return value

def CMB_sec_I3_T_y50(i,L3):
    value = CMB_sec_I3_50_T(i,L3, y50)
    return value

def CMB_sec_I3_T_y100(i,L3):
    value = CMB_sec_I3_100_T(i,L3, y100)
    return value


def CMB_sec_I3_E_y30(i,L3):
    value = CMB_sec_I3_30_E(i,L3, y30)
    return value

def CMB_sec_I3_E_y50(i,L3):
    value = CMB_sec_I3_50_E(i,L3, y50)
    return value

def CMB_sec_I3_E_y100(i,L3):
    value = CMB_sec_I3_100_E(i,L3, y100)
    return value


def CMB_sec_I4_T_y30(i,L3):
    value = CMB_sec_I4_30_T(i,L3, y30)
    return value

def CMB_sec_I4_T_y50(i,L3):
    value = CMB_sec_I4_50_T(i,L3, y50)
    return value

def CMB_sec_I4_T_y100(i,L3):
    value = CMB_sec_I4_100_T(i,L3, y100)
    return value


def CMB_sec_I4_E_y30(i,L3):
    value = CMB_sec_I4_30_E(i,L3, y30)
    return value

def CMB_sec_I4_E_y50(i,L3):
    value = CMB_sec_I4_50_E(i,L3, y50)
    return value

def CMB_sec_I4_E_y100(i,L3):
    value = CMB_sec_I4_100_E(i,L3, y100)
    return value

# %%
# l1-l2-y sampling, k1-, k2-integrations with limber approx

# I1 prim

def Limber21_prim_I1_y30(l1,l2):
    value = y30*W(r30,y30,30,0.1)**2*alp1r(y30)**2*scal_pow(l2/y30)*mono30f(l1/y30)*mono30f(l2/y30)
    return value   

def Limber21_prim_I1_y50(l1,l2):
    value = y50*W(r50,y50,50,0.1)**2*alp1r(y50)**2*scal_pow(l2/y50)*mono50f(l1/y50)*mono50f(l2/y50)
    return value   

def Limber21_prim_I1_y100(l1,l2):
    value = y100*W(r100,y100,100,0.1)**2*alp1r(y100)**2*scal_pow(l2/y100)*mono100f(l1/y100)*mono100f(l2/y100)
    return value

# %%
# l1-l2-y sampling, k1-, k2-integrations with limber approx

# I2 prim


def Limber21_prim_I2_y30(l1,l2):
    value = y30**4*W(r30,y30,30,0.1)**2*alp1r(y30)**2*scal_pow(l1/y30)*scal_pow(l2/y30)*mono30f(l1/y30)*mono30f(l2/y30)
    return value   

def Limber21_prim_I2_y50(l1,l2):
    value = y50**4*W(r50,y50,50,0.1)**2*alp1r(y50)**2*scal_pow(l1/y50)*scal_pow(l2/y50)*mono50f(l1/y50)*mono50f(l2/y50)
    return value   

def Limber21_prim_I2_y100(l1,l2):
    value = y100**4*W(r100,y100,100,0.1)**2*alp1r(y100)**2*scal_pow(l1/y100)*scal_pow(l2/y100)*mono100f(l1/y100)*mono100f(l2/y100)
    return value

# %%
# l1-l2-y sampling, k1-, k2-integrations with limber approx

# I1 sec

def Limber21_sec_I1_y30(l1,l2):
    value = y30*W(r30,y30,30,0.1)**2*scal_pow(l2/y30)*mono30f(l2/y30)**2
    return value   

def Limber21_sec_I1_y50(l1,l2):
    value = y50*W(r50,y50,50,0.1)**2*scal_pow(l2/y50)*mono50f(l2/y50)**2
    return value   

def Limber21_sec_I1_y100(l1,l2):
    value = y100*W(r100,y100,100,0.1)**2*scal_pow(l2/y100)*mono100f(l2/y100)**2
    return value

# %%
# l1-l2-y sampling, k1-, k2-integrations with limber approx

# I2 sec

def Limber21_sec_I2_y30(l1,l2,L2):
    value = 1/L2**2*W(r30,y30,30,0.1)*W(r30,l2/L2*y30,30,0.1)*scal_pow(L2/y30)*mono30f(L2/y30)**2
    return value   

def Limber21_sec_I2_y50(l1,l2,L2):
    value = 1/L2**2*W(r50,y50,50,0.1)*W(r50,l2/L2*y50,50,0.1)*scal_pow(L2/y50)*mono50f(L2/y50)**2
    return value  

def Limber21_sec_I2_y100(l1,l2,L2):
    value = 1/L2**2*W(r100,y100,100,0.1)*W(r100,l2/L2*y100,100,0.1)*scal_pow(L2/y100)*mono100f(L2/y100)**2
    return value

# %%
# l1-l2-y sampling, k1-, k2-integrations with limber approx

# I3 sec

def Limber21_sec_I3_y30(l1,l2,L2):
    value = 1/L2**4*y30**2*W(r30,y30,30,0.1)*W(r30,l2/L2*y30,30,0.1)*scal_pow(L2/y30)*mono30f(L2/y30)**2
    return value   

def Limber21_sec_I3_y50(l1,l2,L2):
    value = 1/L2**4*y50**2*W(r50,y50,50,0.1)*W(r50,l2/L2*y50,50,0.1)*scal_pow(L2/y50)*mono50f(L2/y50)**2
    return value  

def Limber21_sec_I3_y100(l1,l2,L2):
    value = 1/L2**4*y100**2*W(r100,y100,100,0.1)*W(r100,l2/L2*y100,100,0.1)*scal_pow(L2/y100)*mono100f(L2/y100)**2
    return value

# %%
# l1-l2-y sampling, k1-, k2-integrations with limber approx

# I4 sec


def Limber21_sec_I4_y30(l1,l2,L2):
    value = 1/L2**3*y30*W(r30,y30,30,0.1)*W(r30,l2/L2*y30,30,0.1)*scal_pow(L2/y30)*mono30f(L2/y30)**2
    return value   

def Limber21_sec_I4_y50(l1,l2,L2):
    value = 1/L2**3*y50*W(r50,y50,50,0.1)*W(r50,l2/L2*y50,50,0.1)*scal_pow(L2/y50)*mono50f(L2/y50)**2
    return value  

def Limber21_sec_I4_y100(l1,l2,L2):
    value = 1/L2**3*y100*W(r100,y100,100,0.1)*W(r100,l2/L2*y100,100,0.1)*scal_pow(L2/y100)*mono100f(L2/y100)**2
    return value

# %%
# B_21-21-T prim 

# I_1

def B_prim_I1_T_30(l1,l2,l3):
    factor = 192/5*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)*wigner3jm0(l1,l2,l3)
    fI2 = (np.pi/2)**2
    cms = Limber21_prim_I1_y30(l1,l2)/l2**3 + Limber21_prim_I1_y30(l2,l1)/l1**3
    I2= integrate.simps(CMB_prim_I1_T_y30[l3-2]*cms,x=y30)
    value = factor*I2*fI2
    return value


def B_prim_I1_T_50(l1,l2,l3):
    factor = 192/5*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)*wigner3jm0(l1,l2,l3)
    fI2 = (np.pi/2)**2
    cms = Limber21_prim_I1_y50(l1,l2)/l2**3 + Limber21_prim_I1_y50(l2,l1)/l1**3
    I2= integrate.simps(CMB_prim_I1_T_y50[l3-2]*cms,x=y50)
    value = factor*I2*fI2
    return value


def B_prim_I1_T_100(l1,l2,l3):
    factor = 192/5*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)*wigner3jm0(l1,l2,l3)
    fI2 = (np.pi/2)**2
    cms = Limber21_prim_I1_y100(l1,l2)/l2**3 + Limber21_prim_I1_y100(l2,l1)/l1**3
    I2= integrate.simps(CMB_prim_I1_T_y100[l3-2]*cms,x=y100)
    value = factor*I2*fI2
    return value

# %%
# B_21-21-T prim 

# I_2

def B_prim_I2_T_30(l1,l2,l3):
    factor = 192/5*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)*wigner3jm0(l1,l2,l3)
    fI2 = (np.pi/2)**2
    cms = Limber21_prim_I2_y30(l1,l2)/l1**3/l2**3 + Limber21_prim_I2_y30(l2,l1)/l1**3/l2**3
    I2= integrate.simps(CMB_prim_I2_T_y30[l3-2]*cms,x=y30)
    value = factor*I2*fI2
    return value


def B_prim_I2_T_50(l1,l2,l3):
    factor = 192/5*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)*wigner3jm0(l1,l2,l3)
    fI2 = (np.pi/2)**2
    cms = Limber21_prim_I2_y50(l1,l2)/l1**3/l2**3 + Limber21_prim_I2_y50(l2,l1)/l1**3/l2**3
    I2= integrate.simps(CMB_prim_I2_T_y50[l3-2]*cms,x=y50)
    value = factor*I2*fI2
    return value


def B_prim_I2_T_100(l1,l2,l3):
    factor = 192/5*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)*wigner3jm0(l1,l2,l3)
    fI2 = (np.pi/2)**2
    cms = Limber21_prim_I2_y100(l1,l2)/l1**3/l2**3 + Limber21_prim_I2_y100(l2,l1)/l1**3/l2**3
    I2= integrate.simps(CMB_prim_I2_T_y100[l3-2]*cms,x=y100)
    value = factor*I2*fI2
    return value

# %%
# B_21-21-E prim 

# I_1


def B_prim_I1_E_30(l1,l2,l3):
    factor = 192/5*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)*wigner3jm0(l1,l2,l3)
    fI2 = (np.pi/2)**2
    cms = Limber21_prim_I1_y30(l1,l2)/l2**3 + Limber21_prim_I1_y30(l2,l1)/l1**3
    I2= integrate.simps(CMB_prim_I1_E_y30[l3-2]*cms,x=y30)
    value = factor*I2*fI2
    return value


def B_prim_I1_E_50(l1,l2,l3):
    factor = 192/5*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)*wigner3jm0(l1,l2,l3)
    fI2 = (np.pi/2)**2
    cms = Limber21_prim_I1_y50(l1,l2)/l2**3 + Limber21_prim_I1_y50(l2,l1)/l1**3
    I2= integrate.simps(CMB_prim_I1_E_y50[l3-2]*cms,x=y50)
    value = factor*I2*fI2
    return value


def B_prim_I1_E_100(l1,l2,l3):
    factor = 192/5*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)*wigner3jm0(l1,l2,l3)
    fI2 = (np.pi/2)**2
    cms = Limber21_prim_I1_y100(l1,l2)/l2**3 + Limber21_prim_I1_y100(l2,l1)/l1**3
    I2= integrate.simps(CMB_prim_I1_E_y100[l3-2]*cms,x=y100)
    value = factor*I2*fI2
    return value

# %%
# B_21-21-E prim 

# I_2

def B_prim_I2_E_30(l1,l2,l3):
    factor = 192/5*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)*wigner3jm0(l1,l2,l3)
    fI2 = (np.pi/2)**2
    cms = Limber21_prim_I2_y30(l1,l2)/l1**3/l2**3 + Limber21_prim_I2_y30(l2,l1)/l1**3/l2**3
    I2= integrate.simps(CMB_prim_I2_E_y30[l3-2]*cms,x=y30)
    value = factor*I2*fI2
    return value


def B_prim_I2_E_50(l1,l2,l3):
    factor = 192/5*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)*wigner3jm0(l1,l2,l3)
    fI2 = (np.pi/2)**2
    cms = Limber21_prim_I2_y50(l1,l2)/l1**3/l2**3 + Limber21_prim_I2_y50(l2,l1)/l1**3/l2**3
    I2= integrate.simps(CMB_prim_I2_E_y50[l3-2]*cms,x=y50)
    value = factor*I2*fI2
    return value


def B_prim_I2_E_100(l1,l2,l3):
    factor = 192/5*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)*wigner3jm0(l1,l2,l3)
    fI2 = (np.pi/2)**2
    cms = Limber21_prim_I2_y100(l1,l2)/l1**3/l2**3 + Limber21_prim_I2_y100(l2,l1)/l1**3/l2**3
    I2= integrate.simps(CMB_prim_I2_E_y100[l3-2]*cms,x=y100)
    value = factor*I2*fI2
    return value

# %%
# B_21-21-T sec 

# I_1

def B_sec_I1_T_30(l1,l2,l3):
    factor = 64*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)*wigner3jm0(l1,l2,l3)
    fI2 = (np.pi/2)**2
    cms = Limber21_sec_I1_y30(l1,l2)/l2**3 + Limber21_sec_I1_y30(l2,l1)/l1**3
    I2= integrate.simps(CMB_sec_I1_T_y30[l3-2]*cms,x=y30)
    value = factor*I2*fI2
    return value

def B_sec_I1_T_50(l1,l2,l3):
    factor = 64*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)*wigner3jm0(l1,l2,l3)
    fI2 = (np.pi/2)**2
    cms = Limber21_sec_I1_y50(l1,l2)/l2**3 + Limber21_sec_I1_y50(l2,l1)/l1**3
    I2= integrate.simps(CMB_sec_I1_T_y50[l3-2]*cms,x=y50)
    value = factor*I2*fI2
    return value


def B_sec_I1_T_100(l1,l2,l3):
    factor = 64*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)*wigner3jm0(l1,l2,l3)
    fI2 = (np.pi/2)**2
    cms = Limber21_sec_I1_y100(l1,l2)/l2**3 + Limber21_sec_I1_y100(l2,l1)/l1**3
    I2= integrate.simps(CMB_sec_I1_T_y100[l3-2]*cms,x=y100)
    value = factor*I2*fI2
    return value

# %%
# B_21-21-E sec

# I_1

def B_sec_I1_E_30(l1,l2,l3):
    factor = 64*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)*wigner3jm0(l1,l2,l3)
    fI2 = (np.pi/2)**2
    cms = Limber21_sec_I1_y30(l1,l2)/l2**3 + Limber21_sec_I1_y30(l2,l1)/l1**3
    I2= integrate.simps(CMB_sec_I1_E_y30[l3-2]*cms,x=y30)
    value = factor*I2*fI2
    return value

def B_sec_I1_E_50(l1,l2,l3):
    factor = 64*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)*wigner3jm0(l1,l2,l3)
    fI2 = (np.pi/2)**2
    cms = Limber21_sec_I1_y50(l1,l2)/l2**3 + Limber21_sec_I1_y50(l2,l1)/l1**3
    I2= integrate.simps(CMB_sec_I1_E_y50[l3-2]*cms,x=y50)
    value = factor*I2*fI2
    return value


def B_sec_I1_E_100(l1,l2,l3):
    factor = 64*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)*wigner3jm0(l1,l2,l3)
    fI2 = (np.pi/2)**2
    cms = Limber21_sec_I1_y100(l1,l2)/l2**3 + Limber21_sec_I1_y100(l2,l1)/l1**3
    I2= integrate.simps(CMB_sec_I1_E_y100[l3-2]*cms,x=y100)
    value = factor*I2*fI2
    return value

# %%
# B_21-21-T sec 

# I_2

def B_sec_I2_T_30(l1,l2,l3):
    factor = -64*c2*(1j)**(l2+l3)*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)
    fI2 = (np.pi/2)**2
    L2 = [l2-1,l2+1]
    L3 = [l3-1,l3+1]
    I2 = 0   
    for ltwo in L2:
        cms = Limber21_sec_I2_y30(l1,l2,ltwo)/l2 + Limber21_sec_I2_y30(l2,l1,ltwo)/l1
        for lthree in L3:
            cmsf = CMB_sec_I2_T_y30(l3-2,lthree)
            I2 += integrate.simps(cmsf*cms,x=y30)*(2*ltwo+1)*(2*lthree+1)*(1j)**(ltwo+lthree)*wigner3jm0(l1,ltwo,lthree)*wigner3jm0(l2,ltwo,1)*wigner3jm0(l3,lthree,1)*w6j(l1,l2,l3,1,lthree,ltwo)
    value = factor*I2*fI2
    return value.real



def B_sec_I2_T_50(l1,l2,l3):
    factor = -64*c2*(1j)**(l2+l3)*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)
    fI2 = (np.pi/2)**2
    L2 = [l2-1,l2+1]
    L3 = [l3-1,l3+1]
    I2 = 0   
    for ltwo in L2:
        cms = Limber21_sec_I2_y50(l1,l2,ltwo)/l2 + Limber21_sec_I2_y50(l2,l1,ltwo)/l1
        for lthree in L3:
            cmsf = CMB_sec_I2_T_y50(l3-2,lthree)
            I2 += integrate.simps(cmsf*cms,x=y50)*(2*ltwo+1)*(2*lthree+1)*(1j)**(ltwo+lthree)*wigner3jm0(l1,ltwo,lthree)*wigner3jm0(l2,ltwo,1)*wigner3jm0(l3,lthree,1)*w6j(l1,l2,l3,1,lthree,ltwo)
    value = factor*I2*fI2
    return value.real


def B_sec_I2_T_100(l1,l2,l3):
    factor = -64*c2*(1j)**(l2+l3)*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)
    fI2 = (np.pi/2)**2
    L2 = [l2-1,l2+1]
    L3 = [l3-1,l3+1]
    I2 = 0   
    for ltwo in L2:
        cms = Limber21_sec_I2_y100(l1,l2,ltwo)/l2 + Limber21_sec_I2_y100(l2,l1,ltwo)/l1
        for lthree in L3:
            cmsf = CMB_sec_I2_T_y100(l3-2,lthree)
            I2 += integrate.simps(cmsf*cms,x=y100)*(2*ltwo+1)*(2*lthree+1)*(1j)**(ltwo+lthree)*wigner3jm0(l1,ltwo,lthree)*wigner3jm0(l2,ltwo,1)*wigner3jm0(l3,lthree,1)*w6j(l1,l2,l3,1,lthree,ltwo)
    value = factor*I2*fI2
    return value.real

# %%
# B_21-21-E sec

# I_2

def B_sec_I2_E_30(l1,l2,l3):
    factor = -64*c2*(1j)**(l2+l3)*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)
    fI2 = (np.pi/2)**2
    L2 = [l2-1,l2+1]
    L3 = [l3-1,l3+1]
    I2 = 0   
    for ltwo in L2:
        cms = Limber21_sec_I2_y30(l1,l2,ltwo)/l2 + Limber21_sec_I2_y30(l2,l1,ltwo)/l1
        for lthree in L3:
            cmsf = CMB_sec_I2_E_y30(l3-2,lthree)
            I2 += integrate.simps(cmsf*cms,x=y30)*(2*ltwo+1)*(2*lthree+1)*(1j)**(ltwo+lthree)*wigner3jm0(l1,ltwo,lthree)*wigner3jm0(l2,ltwo,1)*wigner3jm0(l3,lthree,1)*w6j(l1,l2,l3,1,lthree,ltwo)
    value = factor*I2*fI2
    return value.real



def B_sec_I2_E_50(l1,l2,l3):
    factor = -64*c2*(1j)**(l2+l3)*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)
    fI2 = (np.pi/2)**2
    L2 = [l2-1,l2+1]
    L3 = [l3-1,l3+1]
    I2 = 0   
    for ltwo in L2:
        cms = Limber21_sec_I2_y50(l1,l2,ltwo)/l2 + Limber21_sec_I2_y50(l2,l1,ltwo)/l1
        for lthree in L3:
            cmsf = CMB_sec_I2_E_y50(l3-2,lthree)
            I2 += integrate.simps(cmsf*cms,x=y50)*(2*ltwo+1)*(2*lthree+1)*(1j)**(ltwo+lthree)*wigner3jm0(l1,ltwo,lthree)*wigner3jm0(l2,ltwo,1)*wigner3jm0(l3,lthree,1)*w6j(l1,l2,l3,1,lthree,ltwo)
    value = factor*I2*fI2
    return value.real


def B_sec_I2_E_100(l1,l2,l3):
    factor = -64*c2*(1j)**(l2+l3)*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)
    fI2 = (np.pi/2)**2
    L2 = [l2-1,l2+1]
    L3 = [l3-1,l3+1]
    I2 = 0   
    for ltwo in L2:
        cms = Limber21_sec_I2_y100(l1,l2,ltwo)/l2 + Limber21_sec_I2_y100(l2,l1,ltwo)/l1
        for lthree in L3:
            cmsf = CMB_sec_I2_E_y100(l3-2,lthree)
            I2 += integrate.simps(cmsf*cms,x=y100)*(2*ltwo+1)*(2*lthree+1)*(1j)**(ltwo+lthree)*wigner3jm0(l1,ltwo,lthree)*wigner3jm0(l2,ltwo,1)*wigner3jm0(l3,lthree,1)*w6j(l1,l2,l3,1,lthree,ltwo)
    value = factor*I2*fI2
    return value.real

# %%
# B_21-21-T sec 

# I_3

def B_sec_I3_T_30(l1,l2,l3):
    factor = -64*c2*(1j)**(l2+l3)*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)
    fI2 = (np.pi/2)**2
    L2 = [l2-1,l2+1]
    L3 = [l3-1,l3+1]
    I2 = 0   
    for ltwo in L2:
        cms = Limber21_sec_I3_y30(l1,l2,ltwo)/l2 + Limber21_sec_I3_y30(l2,l1,ltwo)/l1
        for lthree in L3:
            cmsf = CMB_sec_I3_T_y30(l3-2,lthree)
            I2 += integrate.simps(cmsf*cms,x=y30)*(2*ltwo+1)*(2*lthree+1)*(1j)**(ltwo+lthree)*wigner3jm0(l1,ltwo,lthree)*wigner3jm0(l2,ltwo,1)*wigner3jm0(l3,lthree,1)*w6j(l1,l2,l3,1,lthree,ltwo)
    value = factor*I2*fI2
    return value.real



def B_sec_I3_T_50(l1,l2,l3):
    factor = -64*c2*(1j)**(l2+l3)*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)
    fI2 = (np.pi/2)**2
    L2 = [l2-1,l2+1]
    L3 = [l3-1,l3+1]
    I2 = 0   
    for ltwo in L2:
        cms = Limber21_sec_I3_y50(l1,l2,ltwo)/l2 + Limber21_sec_I3_y50(l2,l1,ltwo)/l1
        for lthree in L3:
            cmsf = CMB_sec_I3_T_y50(l3-2,lthree)
            I2 += integrate.simps(cmsf*cms,x=y50)*(2*ltwo+1)*(2*lthree+1)*(1j)**(ltwo+lthree)*wigner3jm0(l1,ltwo,lthree)*wigner3jm0(l2,ltwo,1)*wigner3jm0(l3,lthree,1)*w6j(l1,l2,l3,1,lthree,ltwo)
    value = factor*I2*fI2
    return value.real


def B_sec_I3_T_100(l1,l2,l3):
    factor = -64*c2*(1j)**(l2+l3)*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)
    fI2 = (np.pi/2)**2
    L2 = [l2-1,l2+1]
    L3 = [l3-1,l3+1]
    I2 = 0   
    for ltwo in L2:
        cms = Limber21_sec_I3_y100(l1,l2,ltwo)/l2 + Limber21_sec_I3_y100(l2,l1,ltwo)/l1
        for lthree in L3:
            cmsf = CMB_sec_I3_T_y100(l3-2,lthree)
            I2 += integrate.simps(cmsf*cms,x=y100)*(2*ltwo+1)*(2*lthree+1)*(1j)**(ltwo+lthree)*wigner3jm0(l1,ltwo,lthree)*wigner3jm0(l2,ltwo,1)*wigner3jm0(l3,lthree,1)*w6j(l1,l2,l3,1,lthree,ltwo)
    value = factor*I2*fI2
    return value.real

# %%
# B_21-21-E sec 

# I_3

def B_sec_I3_E_30(l1,l2,l3):
    factor = -64*c2*(1j)**(l2+l3)*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)
    fI2 = (np.pi/2)**2
    L2 = [l2-1,l2+1]
    L3 = [l3-1,l3+1]
    I2 = 0   
    for ltwo in L2:
        cms = Limber21_sec_I3_y30(l1,l2,ltwo)/l2 + Limber21_sec_I3_y30(l2,l1,ltwo)/l1
        for lthree in L3:
            cmsf = CMB_sec_I3_E_y30(l3-2,lthree)
            I2 += integrate.simps(cmsf*cms,x=y30)*(2*ltwo+1)*(2*lthree+1)*(1j)**(ltwo+lthree)*wigner3jm0(l1,ltwo,lthree)*wigner3jm0(l2,ltwo,1)*wigner3jm0(l3,lthree,1)*w6j(l1,l2,l3,1,lthree,ltwo)
    value = factor*I2*fI2
    return value.real



def B_sec_I3_E_50(l1,l2,l3):
    factor = -64*c2*(1j)**(l2+l3)*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)
    fI2 = (np.pi/2)**2
    L2 = [l2-1,l2+1]
    L3 = [l3-1,l3+1]
    I2 = 0   
    for ltwo in L2:
        cms = Limber21_sec_I3_y50(l1,l2,ltwo)/l2 + Limber21_sec_I3_y50(l2,l1,ltwo)/l1
        for lthree in L3:
            cmsf = CMB_sec_I3_E_y50(l3-2,lthree)
            I2 += integrate.simps(cmsf*cms,x=y50)*(2*ltwo+1)*(2*lthree+1)*(1j)**(ltwo+lthree)*wigner3jm0(l1,ltwo,lthree)*wigner3jm0(l2,ltwo,1)*wigner3jm0(l3,lthree,1)*w6j(l1,l2,l3,1,lthree,ltwo)
    value = factor*I2*fI2
    return value.real


def B_sec_I3_E_100(l1,l2,l3):
    factor = -64*c2*(1j)**(l2+l3)*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)
    fI2 = (np.pi/2)**2
    L2 = [l2-1,l2+1]
    L3 = [l3-1,l3+1]
    I2 = 0   
    for ltwo in L2:
        cms = Limber21_sec_I3_y100(l1,l2,ltwo)/l2 + Limber21_sec_I3_y100(l2,l1,ltwo)/l1
        for lthree in L3:
            cmsf = CMB_sec_I3_E_y100(l3-2,lthree)
            I2 += integrate.simps(cmsf*cms,x=y100)*(2*ltwo+1)*(2*lthree+1)*(1j)**(ltwo+lthree)*wigner3jm0(l1,ltwo,lthree)*wigner3jm0(l2,ltwo,1)*wigner3jm0(l3,lthree,1)*w6j(l1,l2,l3,1,lthree,ltwo)
    value = factor*I2*fI2
    return value.real

# %%
# B_21-21-T sec 

# I_4

def B_sec_I4_T_30(l1,l2,l3):
    factor = 2/3*64*c3*(1j)**(l2+l3)*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)
    fI2 = (np.pi/2)**2
    L2 = [l2-2,l2,l2+2]
    L3 = [l3-2,l3,l3+2]
    I2 = 0   
    for ltwo in L2:
        cms = Limber21_sec_I4_y30(l1,l2,ltwo)/l2 + Limber21_sec_I4_y30(l2,l1,ltwo)/l1
        for lthree in L3:
            cmsf = CMB_sec_I4_T_y30(l3-2,lthree)
            I2 += integrate.simps(cmsf*cms,x=y30)*(2*ltwo+1)*(2*lthree+1)*(1j)**(ltwo+lthree)*wigner3jm0(l1,ltwo,lthree)*wigner3jm0(l2,ltwo,2)*wigner3jm0(l3,lthree,2)*w6j(l1,l2,l3,2,lthree,ltwo)
    value = factor*I2*fI2
    return value.real


def B_sec_I4_T_50(l1,l2,l3):
    factor = 2/3*64*c3*(1j)**(l2+l3)*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)
    fI2 = (np.pi/2)**2
    L2 = [l2-2,l2,l2+2]
    L3 = [l3-2,l3,l3+2]
    I2 = 0   
    for ltwo in L2:
        cms = Limber21_sec_I4_y50(l1,l2,ltwo)/l2 + Limber21_sec_I4_y50(l2,l1,ltwo)/l1
        for lthree in L3:
            cmsf = CMB_sec_I4_T_y50(l3-2,lthree)
            I2 += integrate.simps(cmsf*cms,x=y50)*(2*ltwo+1)*(2*lthree+1)*(1j)**(ltwo+lthree)*wigner3jm0(l1,ltwo,lthree)*wigner3jm0(l2,ltwo,2)*wigner3jm0(l3,lthree,2)*w6j(l1,l2,l3,2,lthree,ltwo)
    value = factor*I2*fI2
    return value.real


def B_sec_I4_T_100(l1,l2,l3):
    factor = 2/3*64*c3*(1j)**(l2+l3)*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)
    fI2 = (np.pi/2)**2
    L2 = [l2-2,l2,l2+2]
    L3 = [l3-2,l3,l3+2]
    I2 = 0   
    for ltwo in L2:
        cms = Limber21_sec_I4_y100(l1,l2,ltwo)/l2 + Limber21_sec_I4_y100(l2,l1,ltwo)/l1
        for lthree in L3:
            cmsf = CMB_sec_I4_T_y100(l3-2,lthree)
            I2 += integrate.simps(cmsf*cms,x=y100)*(2*ltwo+1)*(2*lthree+1)*(1j)**(ltwo+lthree)*wigner3jm0(l1,ltwo,lthree)*wigner3jm0(l2,ltwo,2)*wigner3jm0(l3,lthree,2)*w6j(l1,l2,l3,2,lthree,ltwo)
    value = factor*I2*fI2
    return value.real

# %%
# B_21-21-E sec 

# I_4

def B_sec_I4_E_30(l1,l2,l3):
    factor = 2/3*64*c3*(1j)**(l2+l3)*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)
    fI2 = (np.pi/2)**2
    L2 = [l2-2,l2,l2+2]
    L3 = [l3-2,l3,l3+2]
    I2 = 0   
    for ltwo in L2:
        cms = Limber21_sec_I4_y30(l1,l2,ltwo)/l2 + Limber21_sec_I4_y30(l2,l1,ltwo)/l1
        for lthree in L3:
            cmsf = CMB_sec_I4_E_y30(l3-2,lthree)
            I2 += integrate.simps(cmsf*cms,x=y30)*(2*ltwo+1)*(2*lthree+1)*(1j)**(ltwo+lthree)*wigner3jm0(l1,ltwo,lthree)*wigner3jm0(l2,ltwo,2)*wigner3jm0(l3,lthree,2)*w6j(l1,l2,l3,2,lthree,ltwo)
    value = factor*I2*fI2
    return value.real


def B_sec_I4_E_50(l1,l2,l3):
    factor = 2/3*64*c3*(1j)**(l2+l3)*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)
    fI2 = (np.pi/2)**2
    L2 = [l2-2,l2,l2+2]
    L3 = [l3-2,l3,l3+2]
    I2 = 0   
    for ltwo in L2:
        cms = Limber21_sec_I4_y50(l1,l2,ltwo)/l2 + Limber21_sec_I4_y50(l2,l1,ltwo)/l1
        for lthree in L3:
            cmsf = CMB_sec_I4_E_y50(l3-2,lthree)
            I2 += integrate.simps(cmsf*cms,x=y50)*(2*ltwo+1)*(2*lthree+1)*(1j)**(ltwo+lthree)*wigner3jm0(l1,ltwo,lthree)*wigner3jm0(l2,ltwo,2)*wigner3jm0(l3,lthree,2)*w6j(l1,l2,l3,2,lthree,ltwo)
    value = factor*I2*fI2
    return value.real


def B_sec_I4_E_100(l1,l2,l3):
    factor = 2/3*64*c3*(1j)**(l2+l3)*np.pi*np.sqrt(1/4/np.pi)*np.sqrt(2*l1+1)*np.sqrt(2*l2+1)*np.sqrt(2*l3+1)
    fI2 = (np.pi/2)**2
    L2 = [l2-2,l2,l2+2]
    L3 = [l3-2,l3,l3+2]
    I2 = 0   
    for ltwo in L2:
        cms = Limber21_sec_I4_y100(l1,l2,ltwo)/l2 + Limber21_sec_I4_y100(l2,l1,ltwo)/l1
        for lthree in L3:
            cmsf = CMB_sec_I4_E_y100(l3-2,lthree)
            I2 += integrate.simps(cmsf*cms,x=y100)*(2*ltwo+1)*(2*lthree+1)*(1j)**(ltwo+lthree)*wigner3jm0(l1,ltwo,lthree)*wigner3jm0(l2,ltwo,2)*wigner3jm0(l3,lthree,2)*w6j(l1,l2,l3,2,lthree,ltwo)
    value = factor*I2*fI2
    return value.real

# %%
# Slicings I1-prim <21-21-T>

Bprim30_ll = [B_prim_I1_T_30(10000,10000, l3) for l3 in l3list if l3%2==0]
Bprim50_ll = [B_prim_I1_T_50(10000,10000, l3) for l3 in l3list if l3%2==0]
Bprim100_ll = [B_prim_I1_T_100(10000,10000, l3) for l3 in l3list if l3%2==0]

Bprim30_ll2 = [B_prim_I1_T_30(10000,10002, l3) for l3 in l3list if l3%2==0]
Bprim50_ll2 = [B_prim_I1_T_50(10000,10002, l3) for l3 in l3list if l3%2==0]
Bprim100_ll2 = [B_prim_I1_T_100(10000,10002, l3) for l3 in l3list if l3%2==0]

Bprim30_ll4 = [B_prim_I1_T_30(10000,10004, l3) for l3 in l3list if l3%2==0]
Bprim50_ll4 = [B_prim_I1_T_50(10000,10004, l3) for l3 in l3list if l3%2==0]
Bprim100_ll4 = [B_prim_I1_T_100(10000,10004, l3) for l3 in l3list if l3%2==0]


Bprim30_ll6 = [B_prim_I1_T_30(10000,10006, l3) for l3 in l3list if l3%2==0]
Bprim50_ll6 = [B_prim_I1_T_50(10000,10006, l3) for l3 in l3list if l3%2==0]
Bprim100_ll6 = [B_prim_I1_T_100(10000,10006, l3) for l3 in l3list if l3%2==0]

Bprim30_ll8 = [B_prim_I1_T_30(10000,10008, l3) for l3 in l3list if l3%2==0]
Bprim50_ll8 = [B_prim_I1_T_50(10000,10008, l3) for l3 in l3list if l3%2==0]
Bprim100_ll8 = [B_prim_I1_T_100(10000,10008, l3) for l3 in l3list if l3%2==0]

Bprim30_ll10 = [B_prim_I1_T_30(10000,10010, l3) for l3 in l3list if l3%2==0]
Bprim50_ll10 = [B_prim_I1_T_50(10000,10010, l3) for l3 in l3list if l3%2==0]
Bprim100_ll10 = [B_prim_I1_T_100(10000,10010, l3) for l3 in l3list if l3%2==0]




Bprim30_ll1 = [B_prim_I1_T_30(10000,10001, l3) for l3 in l3list if l3%2==1]
Bprim50_ll1 = [B_prim_I1_T_50(10000,10001, l3) for l3 in l3list if l3%2==1]
Bprim100_ll1 = [B_prim_I1_T_100(10000,10001, l3) for l3 in l3list if l3%2==1]

Bprim30_ll3 = [B_prim_I1_T_30(10000,10003, l3) for l3 in l3list if l3%2==1]
Bprim50_ll3 = [B_prim_I1_T_50(10000,10003, l3) for l3 in l3list if l3%2==1]
Bprim100_ll3 = [B_prim_I1_T_100(10000,10003, l3) for l3 in l3list if l3%2==1]

Bprim30_ll5 = [B_prim_I1_T_30(10000,10005, l3) for l3 in l3list if l3%2==1]
Bprim50_ll5 = [B_prim_I1_T_50(10000,10005, l3) for l3 in l3list if l3%2==1]
Bprim100_ll5 = [B_prim_I1_T_100(10000,10005, l3) for l3 in l3list if l3%2==1]

Bprim30_ll7 = [B_prim_I1_T_30(10000,10007, l3) for l3 in l3list if l3%2==1]
Bprim50_ll7 = [B_prim_I1_T_50(10000,10007, l3) for l3 in l3list if l3%2==1]
Bprim100_ll7 = [B_prim_I1_T_100(10000,10007, l3) for l3 in l3list if l3%2==1]

Bprim30_ll9 = [B_prim_I1_T_30(10000,10009, l3) for l3 in l3list if l3%2==1]
Bprim50_ll9 = [B_prim_I1_T_50(10000,10009, l3) for l3 in l3list if l3%2==1]
Bprim100_ll9 = [B_prim_I1_T_100(10000,10009, l3) for l3 in l3list if l3%2==1]

Bprim30_ll11 = [B_prim_I1_T_30(10000,10011, l3) for l3 in l3list if l3%2==1]
Bprim50_ll11 = [B_prim_I1_T_50(10000,10011, l3) for l3 in l3list if l3%2==1]
Bprim100_ll11 = [B_prim_I1_T_100(10000,10011, l3) for l3 in l3list if l3%2==1]

# %%
# Slicings I2-prim <21-21-T>

Bprim230_ll = [B_prim_I2_T_30(10000,10000, l3) for l3 in l3list if l3%2==0]
Bprim250_ll = [B_prim_I2_T_50(10000,10000, l3) for l3 in l3list if l3%2==0]
Bprim2100_ll = [B_prim_I2_T_100(10000,10000, l3) for l3 in l3list if l3%2==0]


Bprim230_ll1 = [B_prim_I2_T_30(10000,10001, l3) for l3 in l3list if l3%2==1]
Bprim250_ll1 = [B_prim_I2_T_50(10000,10001, l3) for l3 in l3list if l3%2==1]
Bprim2100_ll1 = [B_prim_I2_T_100(10000,10001, l3) for l3 in l3list if l3%2==1]

# Slicings I1-sec <21-21-T>

Bsec130_ll = [B_sec_I1_T_30(10000,10000,l3)*I1c(30) for l3 in l3list if l3%2==0]
Bsec150_ll = [B_sec_I1_T_50(10000,10000,l3)*I1c(50) for l3 in l3list if l3%2==0]
Bsec1100_ll = [B_sec_I1_T_100(10000,10000,l3)*I1c(100) for l3 in l3list if l3%2==0]

Bsec130_ll1 = [B_sec_I1_T_30(10000,10001,l3)*I1c(30) for l3 in l3list if l3%2==1]
Bsec150_ll1 = [B_sec_I1_T_50(10000,10001,l3)*I1c(50) for l3 in l3list if l3%2==1]
Bsec1100_ll1 = [B_sec_I1_T_100(10000,10001,l3)*I1c(100) for l3 in l3list if l3%2==1]

# Slicings I2-sec <21-21-T>

Bsec230_ll = [B_sec_I2_T_30(10000,10000,l3)*I2c(30) for l3 in l3list if l3%2==0]
Bsec250_ll = [B_sec_I2_T_50(10000,10000,l3)*I2c(50) for l3 in l3list if l3%2==0]
Bsec2100_ll = [B_sec_I2_T_100(10000,10000,l3)*I2c(100) for l3 in l3list if l3%2==0]

Bsec230_ll1 = [B_sec_I2_T_30(10000,10001,l3)*I2c(30) for l3 in l3list if l3%2==1]
Bsec250_ll1 = [B_sec_I2_T_50(10000,10001,l3)*I2c(50) for l3 in l3list if l3%2==1]
Bsec2100_ll1 = [B_sec_I2_T_100(10000,10001,l3)*I2c(100) for l3 in l3list if l3%2==1]

# Slicings I3-sec <21-21-T>

Bsec330_ll = [B_sec_I3_T_30(10000,10000,l3)*I2c(30) for l3 in l3list if l3%2==0]
Bsec350_ll = [B_sec_I3_T_50(10000,10000,l3)*I2c(50) for l3 in l3list if l3%2==0]
Bsec3100_ll = [B_sec_I3_T_100(10000,10000,l3)*I2c(100) for l3 in l3list if l3%2==0]

Bsec330_ll1 = [B_sec_I3_T_30(10000,10001,l3)*I2c(30) for l3 in l3list if l3%2==1]
Bsec350_ll1 = [B_sec_I3_T_50(10000,10001,l3)*I2c(50) for l3 in l3list if l3%2==1]
Bsec3100_ll1 = [B_sec_I3_T_100(10000,10001,l3)*I2c(100) for l3 in l3list if l3%2==1]

# Slicings I4-sec <21-21-T>

Bsec430_ll = [B_sec_I4_T_30(10000,10000,l3)*I2c(30) for l3 in l3list if l3%2==0]
Bsec450_ll = [B_sec_I4_T_50(10000,10000,l3)*I2c(50) for l3 in l3list if l3%2==0]
Bsec4100_ll = [B_sec_I4_T_100(10000,10000,l3)*I2c(100) for l3 in l3list if l3%2==0]

Bsec430_ll1 = [B_sec_I4_T_30(10000,10001,l3)*I2c(30) for l3 in l3list if l3%2==1]
Bsec450_ll1 = [B_sec_I4_T_50(10000,10001,l3)*I2c(50) for l3 in l3list if l3%2==1]
Bsec4100_ll1 = [B_sec_I4_T_100(10000,10001,l3)*I2c(100) for l3 in l3list if l3%2==1]

# %%
# Slicings I2-prim <21-21-E>

Bprim230pol_ll = [B_prim_I2_E_30(10000,10000, l3) for l3 in l3list if l3%2==0]
Bprim250pol_ll = [B_prim_I2_E_50(10000,10000, l3) for l3 in l3list if l3%2==0]
Bprim2100pol_ll = [B_prim_I2_E_100(10000,10000, l3) for l3 in l3list if l3%2==0]


Bprim230pol_ll1 = [B_prim_I2_E_30(10000,10001, l3) for l3 in l3list if l3%2==1]
Bprim250pol_ll1 = [B_prim_I2_E_50(10000,10001, l3) for l3 in l3list if l3%2==1]
Bprim2100pol_ll1 = [B_prim_I2_E_100(10000,10001, l3) for l3 in l3list if l3%2==1]

# Slicings I1-sec <21-21-E>

Bsec130pol_ll = [B_sec_I1_E_30(10000,10000,l3)*I1c(30) for l3 in l3list if l3%2==0]
Bsec150pol_ll = [B_sec_I1_E_50(10000,10000,l3)*I1c(50) for l3 in l3list if l3%2==0]
Bsec1100pol_ll = [B_sec_I1_E_100(10000,10000,l3)*I1c(100) for l3 in l3list if l3%2==0]

Bsec130pol_ll1 = [B_sec_I1_E_30(10000,10001,l3)*I1c(30) for l3 in l3list if l3%2==1]
Bsec150pol_ll1 = [B_sec_I1_E_50(10000,10001,l3)*I1c(50) for l3 in l3list if l3%2==1]
Bsec1100pol_ll1 = [B_sec_I1_E_100(10000,10001,l3)*I1c(100) for l3 in l3list if l3%2==1]

# Slicings I2-sec <21-21-E>

Bsec230pol_ll = [B_sec_I2_E_30(10000,10000,l3)*I2c(30) for l3 in l3list if l3%2==0]
Bsec250pol_ll = [B_sec_I2_E_50(10000,10000,l3)*I2c(50) for l3 in l3list if l3%2==0]
Bsec2100pol_ll = [B_sec_I2_E_100(10000,10000,l3)*I2c(100) for l3 in l3list if l3%2==0]

Bsec230pol_ll1 = [B_sec_I2_E_30(10000,10001,l3)*I2c(30) for l3 in l3list if l3%2==1]
Bsec250pol_ll1 = [B_sec_I2_E_50(10000,10001,l3)*I2c(50) for l3 in l3list if l3%2==1]
Bsec2100pol_ll1 = [B_sec_I2_E_100(10000,10001,l3)*I2c(100) for l3 in l3list if l3%2==1]

# Slicings I3-sec <21-21-E>

Bsec330pol_ll = [B_sec_I3_E_30(10000,10000,l3)*I2c(30) for l3 in l3list if l3%2==0]
Bsec350pol_ll = [B_sec_I3_E_50(10000,10000,l3)*I2c(50) for l3 in l3list if l3%2==0]
Bsec3100pol_ll = [B_sec_I3_E_100(10000,10000,l3)*I2c(100) for l3 in l3list if l3%2==0]

Bsec330pol_ll1 = [B_sec_I3_E_30(10000,10001,l3)*I2c(30) for l3 in l3list if l3%2==1]
Bsec350pol_ll1 = [B_sec_I3_E_50(10000,10001,l3)*I2c(50) for l3 in l3list if l3%2==1]
Bsec3100pol_ll1 = [B_sec_I3_E_100(10000,10001,l3)*I2c(100) for l3 in l3list if l3%2==1]

# Slicings I4-sec <21-21-E>

Bsec430pol_ll = [B_sec_I4_E_30(10000,10000,l3)*I2c(30) for l3 in l3list if l3%2==0]
Bsec450pol_ll = [B_sec_I4_E_50(10000,10000,l3)*I2c(50) for l3 in l3list if l3%2==0]
Bsec4100pol_ll = [B_sec_I4_E_100(10000,10000,l3)*I2c(100) for l3 in l3list if l3%2==0]

Bsec430pol_ll1 = [B_sec_I4_E_30(10000,10001,l3)*I2c(30) for l3 in l3list if l3%2==1]
Bsec450pol_ll1 = [B_sec_I4_E_50(10000,10001,l3)*I2c(50) for l3 in l3list if l3%2==1]
Bsec4100pol_ll1 = [B_sec_I4_E_100(10000,10001,l3)*I2c(100) for l3 in l3list if l3%2==1]

# %%
# Slicings full-sec <21-21-T>

Bsec30_ll = [I1c(30)*B_sec_I1_T_30(10000,10000,l3)+I2c(30)*(B_sec_I2_T_30(10000,10000,l3)+B_sec_I3_T_30(10000,10000,l3)+B_sec_I4_T_30(10000,10000,l3)) for l3 in l3list if l3%2==0]
Bsec50_ll = [I1c(50)*B_sec_I1_T_50(10000,10000,l3)+I2c(50)*(B_sec_I2_T_50(10000,10000,l3)+B_sec_I3_T_50(10000,10000,l3)+B_sec_I4_T_50(10000,10000,l3)) for l3 in l3list if l3%2==0]
Bsec100_ll = [I1c(100)*B_sec_I1_T_100(10000,10000,l3)+I2c(100)*(B_sec_I2_T_100(10000,10000,l3)+B_sec_I3_T_100(10000,10000,l3)+B_sec_I4_T_100(10000,10000,l3)) for l3 in l3list if l3%2==0]

Bsec30_ll2 = [I1c(30)*B_sec_I1_T_30(10000,10002,l3)+I2c(30)*(B_sec_I2_T_30(10000,10002,l3)+B_sec_I3_T_30(10000,10002,l3)+B_sec_I4_T_30(10000,10002,l3)) for l3 in l3list if l3%2==0]
Bsec50_ll2 = [I1c(50)*B_sec_I1_T_50(10000,10002,l3)+I2c(50)*(B_sec_I2_T_50(10000,10002,l3)+B_sec_I3_T_50(10000,10002,l3)+B_sec_I4_T_50(10000,10002,l3)) for l3 in l3list if l3%2==0]
Bsec100_ll2 = [I1c(100)*B_sec_I1_T_100(10000,10002,l3)+I2c(100)*(B_sec_I2_T_100(10000,10002,l3)+B_sec_I3_T_100(10000,10002,l3)+B_sec_I4_T_100(10000,10002,l3)) for l3 in l3list if l3%2==0]

Bsec30_ll4 = [I1c(30)*B_sec_I1_T_30(10000,10004,l3)+I2c(30)*(B_sec_I2_T_30(10000,10004,l3)+B_sec_I3_T_30(10000,10004,l3)+B_sec_I4_T_30(10000,10004,l3)) for l3 in l3list if l3%2==0]
Bsec50_ll4 = [I1c(50)*B_sec_I1_T_50(10000,10004,l3)+I2c(50)*(B_sec_I2_T_50(10000,10004,l3)+B_sec_I3_T_50(10000,10004,l3)+B_sec_I4_T_50(10000,10004,l3)) for l3 in l3list if l3%2==0]
Bsec100_ll4 = [I1c(100)*B_sec_I1_T_100(10000,10004,l3)+I2c(100)*(B_sec_I2_T_100(10000,10004,l3)+B_sec_I3_T_100(10000,10004,l3)+B_sec_I4_T_100(10000,10004,l3)) for l3 in l3list if l3%2==0]

Bsec30_ll6 = [I1c(30)*B_sec_I1_T_30(10000,10006,l3)+I2c(30)*(B_sec_I2_T_30(10000,10006,l3)+B_sec_I3_T_30(10000,10006,l3)+B_sec_I4_T_30(10000,10006,l3)) for l3 in l3list if l3%2==0]
Bsec50_ll6 = [I1c(50)*B_sec_I1_T_50(10000,10006,l3)+I2c(50)*(B_sec_I2_T_50(10000,10006,l3)+B_sec_I3_T_50(10000,10006,l3)+B_sec_I4_T_50(10000,10006,l3)) for l3 in l3list if l3%2==0]
Bsec100_ll6 = [I1c(100)*B_sec_I1_T_100(10000,10006,l3)+I2c(100)*(B_sec_I2_T_100(10000,10006,l3)+B_sec_I3_T_100(10000,10006,l3)+B_sec_I4_T_100(10000,10006,l3)) for l3 in l3list if l3%2==0]

Bsec30_ll8 = [I1c(30)*B_sec_I1_T_30(10000,10008,l3)+I2c(30)*(B_sec_I2_T_30(10000,10008,l3)+B_sec_I3_T_30(10000,10008,l3)+B_sec_I4_T_30(10000,10008,l3)) for l3 in l3list if l3%2==0]
Bsec50_ll8 = [I1c(50)*B_sec_I1_T_50(10000,10008,l3)+I2c(50)*(B_sec_I2_T_50(10000,10008,l3)+B_sec_I3_T_50(10000,10008,l3)+B_sec_I4_T_50(10000,10008,l3)) for l3 in l3list if l3%2==0]
Bsec100_ll8 = [I1c(100)*B_sec_I1_T_100(10000,10008,l3)+I2c(100)*(B_sec_I2_T_100(10000,10008,l3)+B_sec_I3_T_100(10000,10008,l3)+B_sec_I4_T_100(10000,10008,l3)) for l3 in l3list if l3%2==0]

Bsec30_ll10 = [I1c(30)*B_sec_I1_T_30(10000,10010,l3)+I2c(30)*(B_sec_I2_T_30(10000,10010,l3)+B_sec_I3_T_30(10000,10010,l3)+B_sec_I4_T_30(10000,10010,l3)) for l3 in l3list if l3%2==0]
Bsec50_ll10 = [I1c(50)*B_sec_I1_T_50(10000,10010,l3)+I2c(50)*(B_sec_I2_T_50(10000,10010,l3)+B_sec_I3_T_50(10000,10010,l3)+B_sec_I4_T_50(10000,10010,l3))for l3 in l3list if l3%2==0]
Bsec100_ll10 = [I1c(100)*B_sec_I1_T_100(10000,10010,l3)+I2c(100)*(B_sec_I2_T_100(10000,10010,l3)+B_sec_I3_T_100(10000,10010,l3)+B_sec_I4_T_100(10000,10010,l3)) for l3 in l3list if l3%2==0]




Bsec30_ll1 = [I1c(30)*B_sec_I1_T_30(10000,10001,l3)+I2c(30)*(B_sec_I2_T_30(10000,10001,l3)+B_sec_I3_T_30(10000,10001,l3)+B_sec_I4_T_30(10000,10001,l3)) for l3 in l3list if l3%2==1]
Bsec50_ll1 = [I1c(50)*B_sec_I1_T_50(10000,10001,l3)+I2c(50)*(B_sec_I2_T_50(10000,10001,l3)+B_sec_I3_T_50(10000,10001,l3)+B_sec_I4_T_50(10000,10001,l3)) for l3 in l3list if l3%2==1]
Bsec100_ll1 = [I1c(100)*B_sec_I1_T_100(10000,10001,l3)+I2c(100)*(B_sec_I2_T_100(10000,10001,l3)+B_sec_I3_T_100(10000,10001,l3)+B_sec_I4_T_100(10000,10001,l3)) for l3 in l3list if l3%2==1]

Bsec30_ll3 = [I1c(30)*B_sec_I1_T_30(10000,10003,l3)+I2c(30)*(B_sec_I2_T_30(10000,10003,l3)+B_sec_I3_T_30(10000,10003,l3)+B_sec_I4_T_30(10000,10003,l3)) for l3 in l3list if l3%2==1]
Bsec50_ll3 = [I1c(50)*B_sec_I1_T_50(10000,10003,l3)+I2c(50)*(B_sec_I2_T_50(10000,10003,l3)+B_sec_I3_T_50(10000,10003,l3)+B_sec_I4_T_50(10000,10003,l3)) for l3 in l3list if l3%2==1]
Bsec100_ll3 = [I1c(100)*B_sec_I1_T_100(10000,10003,l3)+I2c(100)*(B_sec_I2_T_100(10000,10003,l3)+B_sec_I3_T_100(10000,10003,l3)+B_sec_I4_T_100(10000,10003,l3)) for l3 in l3list if l3%2==1]

Bsec30_ll5 = [I1c(30)*B_sec_I1_T_30(10000,10005,l3)+I2c(30)*(B_sec_I2_T_30(10000,10005,l3)+B_sec_I3_T_30(10000,10005,l3)+B_sec_I4_T_30(10000,10005,l3)) for l3 in l3list if l3%2==1]
Bsec50_ll5 = [I1c(50)*B_sec_I1_T_50(10000,10005,l3)+I2c(50)*(B_sec_I2_T_50(10000,10005,l3)+B_sec_I3_T_50(10000,10005,l3)+B_sec_I4_T_50(10000,10005,l3)) for l3 in l3list if l3%2==1]
Bsec100_ll5 = [I1c(100)*B_sec_I1_T_100(10000,10005,l3)+I2c(100)*(B_sec_I2_T_100(10000,10005,l3)+B_sec_I3_T_100(10000,10005,l3)+B_sec_I4_T_100(10000,10005,l3)) for l3 in l3list if l3%2==1]

Bsec30_ll7 = [I1c(30)*B_sec_I1_T_30(10000,10007,l3)+I2c(30)*(B_sec_I2_T_30(10000,10007,l3)+B_sec_I3_T_30(10000,10007,l3)+B_sec_I4_T_30(10000,10007,l3)) for l3 in l3list if l3%2==1]
Bsec50_ll7 = [I1c(50)*B_sec_I1_T_50(10000,10007,l3)+I2c(50)*(B_sec_I2_T_50(10000,10007,l3)+B_sec_I3_T_50(10000,10007,l3)+B_sec_I4_T_50(10000,10007,l3)) for l3 in l3list if l3%2==1]
Bsec100_ll7 = [I1c(100)*B_sec_I1_T_100(10000,10007,l3)+I2c(100)*(B_sec_I2_T_100(10000,10007,l3)+B_sec_I3_T_100(10000,10007,l3)+B_sec_I4_T_100(10000,10007,l3)) for l3 in l3list if l3%2==1]

Bsec30_ll9 = [I1c(30)*B_sec_I1_T_30(10000,10009,l3)+I2c(30)*(B_sec_I2_T_30(10000,10009,l3)+B_sec_I3_T_30(10000,10009,l3)+B_sec_I4_T_30(10000,10009,l3)) for l3 in l3list if l3%2==1]
Bsec50_ll9 = [I1c(50)*B_sec_I1_T_50(10000,10009,l3)+I2c(50)*(B_sec_I2_T_50(10000,10009,l3)+B_sec_I3_T_50(10000,10009,l3)+B_sec_I4_T_50(10000,10009,l3)) for l3 in l3list if l3%2==1]
Bsec100_ll9 = [I1c(100)*B_sec_I1_T_100(10000,10009,l3)+I2c(100)*(B_sec_I2_T_100(10000,10009,l3)+B_sec_I3_T_100(10000,10009,l3)+B_sec_I4_T_100(10000,10009,l3)) for l3 in l3list if l3%2==1]

Bsec30_ll11 = [I1c(30)*B_sec_I1_T_30(10000,10011,l3)+I2c(30)*(B_sec_I2_T_30(10000,10011,l3)+B_sec_I3_T_30(10000,10011,l3)+B_sec_I4_T_30(10000,10011,l3)) for l3 in l3list if l3%2==1]
Bsec50_ll11 = [I1c(50)*B_sec_I1_T_50(10000,10011,l3)+I2c(50)*(B_sec_I2_T_50(10000,10011,l3)+B_sec_I3_T_50(10000,10011,l3)+B_sec_I4_T_50(10000,10011,l3)) for l3 in l3list if l3%2==1]
Bsec100_ll11 = [I1c(100)*B_sec_I1_T_100(10000,10011,l3)+I2c(100)*(B_sec_I2_T_100(10000,10011,l3)+B_sec_I3_T_100(10000,10011,l3)+B_sec_I4_T_100(10000,10011,l3)) for l3 in l3list if l3%2==1]




l3plote = [l3 for l3 in l3list if l3%2==0]
l3ploto = [l3 for l3 in l3list if l3%2==1]

# %%
# Slicings prim-I1 <21-21-E>


Bprim30pol_ll = [B_prim_I1_E_30(10000,10000, l3) for l3 in l3list if l3%2==0]
Bprim50pol_ll = [B_prim_I1_E_50(10000,10000, l3) for l3 in l3list if l3%2==0]
Bprim100pol_ll = [B_prim_I1_E_100(10000,10000, l3) for l3 in l3list if l3%2==0]

Bprim30pol_ll2 = [B_prim_I1_E_30(10000,10002, l3) for l3 in l3list if l3%2==0]
Bprim50pol_ll2 = [B_prim_I1_E_50(10000,10002, l3) for l3 in l3list if l3%2==0]
Bprim100pol_ll2 = [B_prim_I1_E_100(10000,10002, l3) for l3 in l3list if l3%2==0]

Bprim30pol_ll4 = [B_prim_I1_E_30(10000,10004, l3) for l3 in l3list if l3%2==0]
Bprim50pol_ll4 = [B_prim_I1_E_50(10000,10004, l3) for l3 in l3list if l3%2==0]
Bprim100pol_ll4 = [B_prim_I1_E_100(10000,10004, l3) for l3 in l3list if l3%2==0]


Bprim30pol_ll6 = [B_prim_I1_E_30(10000,10006, l3) for l3 in l3list if l3%2==0]
Bprim50pol_ll6 = [B_prim_I1_E_50(10000,10006, l3) for l3 in l3list if l3%2==0]
Bprim100pol_ll6 = [B_prim_I1_E_100(10000,10006, l3) for l3 in l3list if l3%2==0]

Bprim30pol_ll8 = [B_prim_I1_E_30(10000,10008, l3) for l3 in l3list if l3%2==0]
Bprim50pol_ll8 = [B_prim_I1_E_50(10000,10008, l3) for l3 in l3list if l3%2==0]
Bprim100pol_ll8 = [B_prim_I1_E_100(10000,10008, l3) for l3 in l3list if l3%2==0]

Bprim30pol_ll10 = [B_prim_I1_E_30(10000,10010, l3) for l3 in l3list if l3%2==0]
Bprim50pol_ll10 = [B_prim_I1_E_50(10000,10010, l3) for l3 in l3list if l3%2==0]
Bprim100pol_ll10 = [B_prim_I1_E_100(10000,10010, l3) for l3 in l3list if l3%2==0]




Bprim30pol_ll1 = [B_prim_I1_E_30(10000,10001, l3) for l3 in l3list if l3%2==1]
Bprim50pol_ll1 = [B_prim_I1_E_50(10000,10001, l3) for l3 in l3list if l3%2==1]
Bprim100pol_ll1 = [B_prim_I1_E_100(10000,10001, l3) for l3 in l3list if l3%2==1]

Bprim30pol_ll3 = [B_prim_I1_E_30(10000,10003, l3) for l3 in l3list if l3%2==1]
Bprim50pol_ll3 = [B_prim_I1_E_50(10000,10003, l3) for l3 in l3list if l3%2==1]
Bprim100pol_ll3 = [B_prim_I1_E_100(10000,10003, l3) for l3 in l3list if l3%2==1]

Bprim30pol_ll5 = [B_prim_I1_E_30(10000,10005, l3) for l3 in l3list if l3%2==1]
Bprim50pol_ll5 = [B_prim_I1_E_50(10000,10005, l3) for l3 in l3list if l3%2==1]
Bprim100pol_ll5 = [B_prim_I1_E_100(10000,10005, l3) for l3 in l3list if l3%2==1]

Bprim30pol_ll7 = [B_prim_I1_E_30(10000,10007, l3) for l3 in l3list if l3%2==1]
Bprim50pol_ll7 = [B_prim_I1_E_50(10000,10007, l3) for l3 in l3list if l3%2==1]
Bprim100pol_ll7 = [B_prim_I1_E_100(10000,10007, l3) for l3 in l3list if l3%2==1]

Bprim30pol_ll9 = [B_prim_I1_E_30(10000,10009, l3) for l3 in l3list if l3%2==1]
Bprim50pol_ll9 = [B_prim_I1_E_50(10000,10009, l3) for l3 in l3list if l3%2==1]
Bprim100pol_ll9 = [B_prim_I1_E_100(10000,10009, l3) for l3 in l3list if l3%2==1]

Bprim30pol_ll11 = [B_prim_I1_E_30(10000,10011, l3) for l3 in l3list if l3%2==1]
Bprim50pol_ll11 = [B_prim_I1_E_50(10000,10011, l3) for l3 in l3list if l3%2==1]
Bprim100pol_ll11 = [B_prim_I1_E_100(10000,10011, l3) for l3 in l3list if l3%2==1]

# %%
# Slicings full-sec <21-21-E>

Bsec30pol_ll = [I1c(30)*B_sec_I1_E_30(10000,10000,l3)+I2c(30)*(B_sec_I2_E_30(10000,10000,l3)+B_sec_I3_E_30(10000,10000,l3)+B_sec_I4_E_30(10000,10000,l3)) for l3 in l3list if l3%2==0]
Bsec50pol_ll = [I1c(50)*B_sec_I1_E_50(10000,10000,l3)+I2c(50)*(B_sec_I2_E_50(10000,10000,l3)+B_sec_I3_E_50(10000,10000,l3)+B_sec_I4_E_50(10000,10000,l3)) for l3 in l3list if l3%2==0]
Bsec100pol_ll = [I1c(100)*B_sec_I1_E_100(10000,10000,l3)+I2c(100)*(B_sec_I2_E_100(10000,10000,l3)+B_sec_I3_E_100(10000,10000,l3)+B_sec_I4_E_100(10000,10000,l3)) for l3 in l3list if l3%2==0]

Bsec30pol_ll2 = [I1c(30)*B_sec_I1_E_30(10000,10002,l3)+I2c(30)*(B_sec_I2_E_30(10000,10002,l3)+B_sec_I3_E_30(10000,10002,l3)+B_sec_I4_E_30(10000,10002,l3)) for l3 in l3list if l3%2==0]
Bsec50pol_ll2 = [I1c(50)*B_sec_I1_E_50(10000,10002,l3)+I2c(50)*(B_sec_I2_E_50(10000,10002,l3)+B_sec_I3_E_50(10000,10002,l3)+B_sec_I4_E_50(10000,10002,l3)) for l3 in l3list if l3%2==0]
Bsec100pol_ll2 = [I1c(100)*B_sec_I1_E_100(10000,10002,l3)+I2c(100)*(B_sec_I2_E_100(10000,10002,l3)+B_sec_I3_E_100(10000,10002,l3)+B_sec_I4_E_100(10000,10002,l3)) for l3 in l3list if l3%2==0]

Bsec30pol_ll4 = [I1c(30)*B_sec_I1_E_30(10000,10004,l3)+I2c(30)*(B_sec_I2_E_30(10000,10004,l3)+B_sec_I3_E_30(10000,10004,l3)+B_sec_I4_E_30(10000,10004,l3)) for l3 in l3list if l3%2==0]
Bsec50pol_ll4 = [I1c(50)*B_sec_I1_E_50(10000,10004,l3)+I2c(50)*(B_sec_I2_E_50(10000,10004,l3)+B_sec_I3_E_50(10000,10004,l3)+B_sec_I4_E_50(10000,10004,l3)) for l3 in l3list if l3%2==0]
Bsec100pol_ll4 = [I1c(100)*B_sec_I1_E_100(10000,10004,l3)+I2c(100)*(B_sec_I2_E_100(10000,10004,l3)+B_sec_I3_E_100(10000,10004,l3)+B_sec_I4_E_100(10000,10004,l3)) for l3 in l3list if l3%2==0]

Bsec30pol_ll6 = [I1c(30)*B_sec_I1_E_30(10000,10006,l3)+I2c(30)*(B_sec_I2_E_30(10000,10006,l3)+B_sec_I3_E_30(10000,10006,l3)+B_sec_I4_E_30(10000,10006,l3)) for l3 in l3list if l3%2==0]
Bsec50pol_ll6 = [I1c(50)*B_sec_I1_E_50(10000,10006,l3)+I2c(50)*(B_sec_I2_E_50(10000,10006,l3)+B_sec_I3_E_50(10000,10006,l3)+B_sec_I4_E_50(10000,10006,l3)) for l3 in l3list if l3%2==0]
Bsec100pol_ll6 = [I1c(100)*B_sec_I1_E_100(10000,10006,l3)+I2c(100)*(B_sec_I2_E_100(10000,10006,l3)+B_sec_I3_E_100(10000,10006,l3)+B_sec_I4_E_100(10000,10006,l3)) for l3 in l3list if l3%2==0]

Bsec30pol_ll8 = [I1c(30)*B_sec_I1_E_30(10000,10008,l3)+I2c(30)*(B_sec_I2_E_30(10000,10008,l3)+B_sec_I3_E_30(10000,10008,l3)+B_sec_I4_E_30(10000,10008,l3)) for l3 in l3list if l3%2==0]
Bsec50pol_ll8 = [I1c(50)*B_sec_I1_E_50(10000,10008,l3)+I2c(50)*(B_sec_I2_E_50(10000,10008,l3)+B_sec_I3_E_50(10000,10008,l3)+B_sec_I4_E_50(10000,10008,l3)) for l3 in l3list if l3%2==0]
Bsec100pol_ll8 = [I1c(100)*B_sec_I1_E_100(10000,10008,l3)+I2c(100)*(B_sec_I2_E_100(10000,10008,l3)+B_sec_I3_E_100(10000,10008,l3)+B_sec_I4_E_100(10000,10008,l3)) for l3 in l3list if l3%2==0]

Bsec30pol_ll10 = [I1c(30)*B_sec_I1_E_30(10000,10010,l3)+I2c(30)*(B_sec_I2_E_30(10000,10010,l3)+B_sec_I3_E_30(10000,10010,l3)+B_sec_I4_E_30(10000,10010,l3)) for l3 in l3list if l3%2==0]
Bsec50pol_ll10 = [I1c(50)*B_sec_I1_E_50(10000,10010,l3)+I2c(50)*(B_sec_I2_E_50(10000,10010,l3)+B_sec_I3_E_50(10000,10010,l3)+B_sec_I4_E_50(10000,10010,l3)) for l3 in l3list if l3%2==0]
Bsec100pol_ll10 = [I1c(100)*B_sec_I1_E_100(10000,10010,l3)+I2c(100)*(B_sec_I2_E_100(10000,10010,l3)+B_sec_I3_E_100(10000,10010,l3)+B_sec_I4_E_100(10000,10010,l3)) for l3 in l3list if l3%2==0]




Bsec30pol_ll1 = [I1c(30)*B_sec_I1_E_30(10000,10001,l3)+I2c(30)*(B_sec_I2_E_30(10000,10001,l3)+B_sec_I3_E_30(10000,10001,l3)+B_sec_I4_E_30(10000,10001,l3)) for l3 in l3list if l3%2==1]
Bsec50pol_ll1 = [I1c(50)*B_sec_I1_E_50(10000,10001,l3)+I2c(50)*(B_sec_I2_E_50(10000,10001,l3)+B_sec_I3_E_50(10000,10001,l3)+B_sec_I4_E_50(10000,10001,l3)) for l3 in l3list if l3%2==1]
Bsec100pol_ll1 = [I1c(100)*B_sec_I1_E_100(10000,10001,l3)+I2c(100)*(B_sec_I2_E_100(10000,10001,l3)+B_sec_I3_E_100(10000,10001,l3)+B_sec_I4_E_100(10000,10001,l3)) for l3 in l3list if l3%2==1]

Bsec30pol_ll3 = [I1c(30)*B_sec_I1_E_30(10000,10003,l3)+I2c(30)*(B_sec_I2_E_30(10000,10003,l3)+B_sec_I3_E_30(10000,10003,l3)+B_sec_I4_E_30(10000,10003,l3)) for l3 in l3list if l3%2==1]
Bsec50pol_ll3 = [I1c(50)*B_sec_I1_E_50(10000,10003,l3)+I2c(50)*(B_sec_I2_E_50(10000,10003,l3)+B_sec_I3_E_50(10000,10003,l3)+B_sec_I4_E_50(10000,10003,l3)) for l3 in l3list if l3%2==1]
Bsec100pol_ll3 = [I1c(100)*B_sec_I1_E_100(10000,10003,l3)+I2c(100)*(B_sec_I2_E_100(10000,10003,l3)+B_sec_I3_E_100(10000,10003,l3)+B_sec_I4_E_100(10000,10003,l3)) for l3 in l3list if l3%2==1]

Bsec30pol_ll5 = [I1c(30)*B_sec_I1_E_30(10000,10005,l3)+I2c(30)*(B_sec_I2_E_30(10000,10005,l3)+B_sec_I3_E_30(10000,10005,l3)+B_sec_I4_E_30(10000,10005,l3)) for l3 in l3list if l3%2==1]
Bsec50pol_ll5 = [I1c(50)*B_sec_I1_E_50(10000,10005,l3)+I2c(50)*(B_sec_I2_E_50(10000,10005,l3)+B_sec_I3_E_50(10000,10005,l3)+B_sec_I4_E_50(10000,10005,l3)) for l3 in l3list if l3%2==1]
Bsec100pol_ll5 = [I1c(100)*B_sec_I1_E_100(10000,10005,l3)+I2c(100)*(B_sec_I2_E_100(10000,10005,l3)+B_sec_I3_E_100(10000,10005,l3)+B_sec_I4_E_100(10000,10005,l3)) for l3 in l3list if l3%2==1]

Bsec30pol_ll7 = [I1c(30)*B_sec_I1_E_30(10000,10007,l3)+I2c(30)*(B_sec_I2_E_30(10000,10007,l3)+B_sec_I3_E_30(10000,10007,l3)+B_sec_I4_E_30(10000,10007,l3)) for l3 in l3list if l3%2==1]
Bsec50pol_ll7 = [I1c(50)*B_sec_I1_E_50(10000,10007,l3)+I2c(50)*(B_sec_I2_E_50(10000,10007,l3)+B_sec_I3_E_50(10000,10007,l3)+B_sec_I4_E_50(10000,10007,l3)) for l3 in l3list if l3%2==1]
Bsec100pol_ll7 = [I1c(100)*B_sec_I1_E_100(10000,10007,l3)+I2c(100)*(B_sec_I2_E_100(10000,10007,l3)+B_sec_I3_E_100(10000,10007,l3)+B_sec_I4_E_100(10000,10007,l3)) for l3 in l3list if l3%2==1]

Bsec30pol_ll9 = [I1c(30)*B_sec_I1_E_30(10000,10009,l3)+I2c(30)*(B_sec_I2_E_30(10000,10009,l3)+B_sec_I3_E_30(10000,10009,l3)+B_sec_I4_E_30(10000,10009,l3)) for l3 in l3list if l3%2==1]
Bsec50pol_ll9 = [I1c(50)*B_sec_I1_E_50(10000,10009,l3)+I2c(50)*(B_sec_I2_E_50(10000,10009,l3)+B_sec_I3_E_50(10000,10009,l3)+B_sec_I4_E_50(10000,10009,l3)) for l3 in l3list if l3%2==1]
Bsec100pol_ll9 = [I1c(100)*B_sec_I1_E_100(10000,10009,l3)+I2c(100)*(B_sec_I2_E_100(10000,10009,l3)+B_sec_I3_E_100(10000,10009,l3)+B_sec_I4_E_100(10000,10009,l3)) for l3 in l3list if l3%2==1]

Bsec30pol_ll11 = [I1c(30)*B_sec_I1_E_30(10000,10011,l3)+I2c(30)*(B_sec_I2_E_30(10000,10011,l3)+B_sec_I3_E_30(10000,10011,l3)+B_sec_I4_E_30(10000,10011,l3)) for l3 in l3list if l3%2==1]
Bsec50pol_ll11 = [I1c(50)*B_sec_I1_E_50(10000,10011,l3)+I2c(50)*(B_sec_I2_E_50(10000,10011,l3)+B_sec_I3_E_50(10000,10011,l3)+B_sec_I4_E_50(10000,10011,l3)) for l3 in l3list if l3%2==1]
Bsec100pol_ll11 = [I1c(100)*B_sec_I1_E_100(10000,10011,l3)+I2c(100)*(B_sec_I2_E_100(10000,10011,l3)+B_sec_I3_E_100(10000,10011,l3)+B_sec_I4_E_100(10000,10011,l3)) for l3 in l3list if l3%2==1]

# %%
# Slicings I1-sec <21-21-E>

Bsec30pol_ll = [I1c(30)*B_sec_I1_E_30(10000,10000,l3) for l3 in l3list if l3%2==0]
Bsec50pol_ll = [I1c(50)*B_sec_I1_E_50(10000,10000,l3) for l3 in l3list if l3%2==0]
Bsec100pol_ll = [I1c(100)*B_sec_I1_E_100(10000,10000,l3) for l3 in l3list if l3%2==0]

Bsec30pol_ll2 = [I1c(30)*B_sec_I1_E_30(10000,10002,l3) for l3 in l3list if l3%2==0]
Bsec50pol_ll2 = [I1c(50)*B_sec_I1_E_50(10000,10002,l3) for l3 in l3list if l3%2==0]
Bsec100pol_ll2 = [I1c(100)*B_sec_I1_E_100(10000,10002,l3) for l3 in l3list if l3%2==0]

# %%
# plot prim/sec <21-21-T>

fig, ((ax1,ax7), (ax2,ax8), (ax3,ax9), (ax4,ax10), (ax5,ax11)) = plt.subplots(nrows=5, ncols=2, figsize=(9, 15))


fig.suptitle('Cross-correlation with T', fontsize=20,y=0.95)

fig.subplots_adjust(hspace=0.7)
fig.subplots_adjust(wspace=0.3)


ax1.set_title(r'$\ell_1 = \ell_2 \qquad$ $ \ell_3=$ even', fontsize=18)
ax2.set_title(r'$\ell_1 = \ell_2+2 \qquad$ $\ell_3=$ even', fontsize=18)
ax3.set_title(r'$\ell_1 = \ell_2+4 \qquad$ $\ell_3=$ even', fontsize=18)
ax4.set_title(r'$\ell_1 = \ell_2+6 \qquad$ $\ell_3=$ even', fontsize=18)
ax5.set_title(r'$\ell_1 = \ell_2+8 \qquad$ $\ell_3=$ even', fontsize=18)

ax7.set_title(r'$\ell_1 = \ell_2+1 \qquad$ $\ell_3=$ odd', fontsize=18)
ax8.set_title(r'$\ell_1 = \ell_2+3 \qquad$ $\ell_3=$ odd', fontsize=18)
ax9.set_title(r'$\ell_1 = \ell_2+5 \qquad$ $\ell_3=$ odd', fontsize=18)
ax10.set_title(r'$\ell_1 = \ell_2+7 \qquad$ $\ell_3=$ odd', fontsize=18)
ax11.set_title(r'$\ell_1 = \ell_2+9 \qquad$ $\ell_3=$ odd', fontsize=18)


ax1.set_xlabel(r'$\ell_3$', fontsize=18)
ax2.set_xlabel(r'$\ell_3$', fontsize=18)
ax3.set_xlabel(r'$\ell_3$', fontsize=18)
ax4.set_xlabel(r'$\ell_3$', fontsize=18)
ax5.set_xlabel(r'$\ell_3$', fontsize=18)

ax7.set_xlabel(r'$\ell_3$', fontsize=18)
ax8.set_xlabel(r'$\ell_3$', fontsize=18)
ax9.set_xlabel(r'$\ell_3$', fontsize=18)
ax10.set_xlabel(r'$\ell_3$', fontsize=18)
ax11.set_xlabel(r'$\ell_3$', fontsize=18)



ax1.set_xlim(1,12)
ax2.set_xlim(1,12)
ax3.set_xlim(1,12)
ax4.set_xlim(1,12)
ax5.set_xlim(1,12)

ax7.set_xlim(1,12)
ax8.set_xlim(1,12)
ax9.set_xlim(1,12)
ax10.set_xlim(1,12)
ax11.set_xlim(1,12)



ax1.set_ylabel(r'$|B_{\ell_1 \ell_2 \ell_3}^{\rm prim}/B_{\ell_1 \ell_2 \ell_3}^{\rm sec}|$', fontsize=18)
ax2.set_ylabel(r'$|B_{\ell_1 \ell_2 \ell_3}^{\rm prim}/B_{\ell_1 \ell_2 \ell_3}^{\rm sec}|$', fontsize=18)
ax3.set_ylabel(r'$|B_{\ell_1 \ell_2 \ell_3}^{\rm prim}/B_{\ell_1 \ell_2 \ell_3}^{\rm sec}|$', fontsize=18)
ax4.set_ylabel(r'$|B_{\ell_1 \ell_2 \ell_3}^{\rm prim}/B_{\ell_1 \ell_2 \ell_3}^{\rm sec}|$', fontsize=18)
ax5.set_ylabel(r'$|B_{\ell_1 \ell_2 \ell_3}^{\rm prim}/B_{\ell_1 \ell_2 \ell_3}^{\rm sec}|$', fontsize=18)

ax1.set_yscale('log')
ax2.set_yscale('log')
ax3.set_yscale('log')
ax4.set_yscale('log')
ax5.set_yscale('log')

ax7.set_yscale('log')
ax8.set_yscale('log')
ax9.set_yscale('log')
ax10.set_yscale('log')
ax11.set_yscale('log')


ax1.plot(l3plote,np.abs(np.array(Bprim30_ll)/np.array(Bsec30_ll)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax1.plot(l3plote,np.abs(np.array(Bprim50_ll)/np.array(Bsec50_ll)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax1.plot(l3plote,np.abs(np.array(Bprim100_ll)/np.array(Bsec100_ll)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)



ax2.plot(l3plote,np.abs(np.array(Bprim30_ll2)/np.array(Bsec30_ll2)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax2.plot(l3plote,np.abs(np.array(Bprim50_ll2)/np.array(Bsec50_ll2)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax2.plot(l3plote,np.abs(np.array(Bprim100_ll2)/np.array(Bsec100_ll2)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)

ax3.plot(l3plote[1:],np.abs(np.array(Bprim30_ll4)[1:]/np.array(Bsec30_ll4)[1:]),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax3.plot(l3plote[1:],np.abs(np.array(Bprim50_ll4)[1:]/np.array(Bsec50_ll4)[1:]),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax3.plot(l3plote[1:],np.abs(np.array(Bprim100_ll4)[1:]/np.array(Bsec100_ll4)[1:]),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)

ax4.plot(l3plote[2:],np.abs(np.array(Bprim30_ll6)[2:]/np.array(Bsec30_ll6)[2:]),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax4.plot(l3plote[2:],np.abs(np.array(Bprim50_ll6)[2:]/np.array(Bsec50_ll6)[2:]),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax4.plot(l3plote[2:],np.abs(np.array(Bprim100_ll6)[2:]/np.array(Bsec100_ll6)[2:]),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)

ax5.plot(l3plote[3:],np.abs(np.array(Bprim30_ll8)[3:]/np.array(Bsec30_ll8)[3:]),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax5.plot(l3plote[3:],np.abs(np.array(Bprim50_ll8)[3:]/np.array(Bsec50_ll8)[3:]),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax5.plot(l3plote[3:],np.abs(np.array(Bprim100_ll8)[3:]/np.array(Bsec100_ll8)[3:]),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)




ax7.plot(l3ploto,np.abs(np.array(Bprim30_ll1)/np.array(Bsec30_ll1)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax7.plot(l3ploto,np.abs(np.array(Bprim50_ll1)/np.array(Bsec50_ll1)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax7.plot(l3ploto,np.abs(np.array(Bprim100_ll1)/np.array(Bsec100_ll1)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)

ax7.legend(bbox_to_anchor=(1.3, 0.80), loc='center', ncol = 1, borderaxespad=0., fontsize=15)#(loc='best', fontsize=20)



ax8.plot(l3ploto,np.abs(np.array(Bprim30_ll3)/np.array(Bsec30_ll3)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax8.plot(l3ploto,np.abs(np.array(Bprim50_ll3)/np.array(Bsec50_ll3)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax8.plot(l3ploto,np.abs(np.array(Bprim100_ll3)/np.array(Bsec100_ll3)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)

ax9.plot(l3ploto[1:],np.abs(np.array(Bprim30_ll5)[1:]/np.array(Bsec30_ll5)[1:]),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax9.plot(l3ploto[1:],np.abs(np.array(Bprim50_ll5)[1:]/np.array(Bsec50_ll5)[1:]),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax9.plot(l3ploto[1:],np.abs(np.array(Bprim100_ll5)[1:]/np.array(Bsec100_ll5)[1:]),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)

ax10.plot(l3ploto[2:],np.abs(np.array(Bprim30_ll7)[2:]/np.array(Bsec30_ll7)[2:]),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax10.plot(l3ploto[2:],np.abs(np.array(Bprim50_ll7)[2:]/np.array(Bsec50_ll7)[2:]),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax10.plot(l3ploto[2:],np.abs(np.array(Bprim100_ll7)[2:]/np.array(Bsec100_ll7)[2:]),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)

ax11.plot(l3ploto[3:],np.abs(np.array(Bprim30_ll9)[3:]/np.array(Bsec30_ll9)[3:]),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax11.plot(l3ploto[3:],np.abs(np.array(Bprim50_ll9)[3:]/np.array(Bsec50_ll9)[3:]),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax11.plot(l3ploto[3:],np.abs(np.array(Bprim100_ll9)[3:]/np.array(Bsec100_ll9)[3:]),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)


plt.savefig("plots/prims_vs_sec.pdf", dpi=300, bbox_inches='tight')


plt.show()
plt.close()

# %%
# plot prim1/otherprim and sec1/othersec, <21-21-T>

fig, ((ax1,ax2),(ax3,ax4),(ax5,ax6),(ax7,ax8)) = plt.subplots(nrows=4, ncols=2, figsize=(9, 13))



fig.suptitle('Cross-correlation with T', fontsize=20,y=0.95)




fig.subplots_adjust(hspace=0.7)
fig.subplots_adjust(wspace=0.3)


ax1.set_title(r'$\ell_1 \simeq \ell_2 = 10^4 \qquad$ $ \ell_3=$ even', fontsize=18)
ax2.set_title(r'$\ell_1 \simeq \ell_2 = 10^4 \qquad$ $ \ell_3=$ odd', fontsize=18)



ax1.set_xlabel(r'$\ell_3$', fontsize=18)
ax2.set_xlabel(r'$\ell_3$', fontsize=18)

ax3.set_xlabel(r'$\ell_3$', fontsize=18)
ax4.set_xlabel(r'$\ell_3$', fontsize=18)

ax5.set_xlabel(r'$\ell_3$', fontsize=18)
ax6.set_xlabel(r'$\ell_3$', fontsize=18)

ax7.set_xlabel(r'$\ell_3$', fontsize=18)
ax8.set_xlabel(r'$\ell_3$', fontsize=18)





ax1.set_xlim(1,12)
ax2.set_xlim(1,12)
ax3.set_xlim(1,12)
ax4.set_xlim(1,12)
ax5.set_xlim(1,12)
ax6.set_xlim(1,12)
ax7.set_xlim(1,12)
ax8.set_xlim(1,12)




ax1.set_ylabel(r'$|B_{\ell_1 \ell_2 \ell_3}^{\rm prim, 1}/B_{\ell_1 \ell_2 \ell_3}^{\rm prim, 2}|$', fontsize=18)


ax3.set_ylabel(r'$|B_{\ell_1 \ell_2 \ell_3}^{\rm sec, 1}/B_{\ell_1 \ell_2 \ell_3}^{\rm sec, 2}|$', fontsize=18)


ax5.set_ylabel(r'$|B_{\ell_1 \ell_2 \ell_3}^{\rm sec, 1}/B_{\ell_1 \ell_2 \ell_3}^{\rm sec, 3}|$', fontsize=18)


ax7.set_ylabel(r'$|B_{\ell_1 \ell_2 \ell_3}^{\rm sec, 1}/B_{\ell_1 \ell_2 \ell_3}^{\rm sec, 4}|$', fontsize=18)



ax1.set_yscale('log')
ax2.set_yscale('log')
ax3.set_yscale('log')
ax4.set_yscale('log')
ax5.set_yscale('log')
ax6.set_yscale('log')
ax7.set_yscale('log')
ax8.set_yscale('log')

ax1.plot(l3plote,np.abs(np.array(Bprim30_ll)/np.array(Bprim230_ll)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax1.plot(l3plote,np.abs(np.array(Bprim50_ll)/np.array(Bprim250_ll)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax1.plot(l3plote,np.abs(np.array(Bprim100_ll)/np.array(Bprim2100_ll)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)


ax2.plot(l3ploto,np.abs(np.array(Bprim30_ll1)/np.array(Bprim230_ll1)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax2.plot(l3ploto,np.abs(np.array(Bprim50_ll1)/np.array(Bprim250_ll1)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax2.plot(l3ploto,np.abs(np.array(Bprim100_ll1)/np.array(Bprim2100_ll1)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)

ax2.legend(bbox_to_anchor=(1.3, 0.80), loc='center', ncol = 1, borderaxespad=0., fontsize=15)#(loc='best', fontsize=20)


ax3.plot(l3plote,np.abs(np.array(Bsec130_ll)/np.array(Bsec230_ll)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax3.plot(l3plote,np.abs(np.array(Bsec150_ll)/np.array(Bsec250_ll)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax3.plot(l3plote,np.abs(np.array(Bsec1100_ll)/np.array(Bsec2100_ll)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)


ax4.plot(l3ploto,np.abs(np.array(Bsec130_ll1)/np.array(Bsec230_ll1)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax4.plot(l3ploto,np.abs(np.array(Bsec150_ll1)/np.array(Bsec250_ll1)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax4.plot(l3ploto,np.abs(np.array(Bsec1100_ll1)/np.array(Bsec2100_ll1)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)


ax5.plot(l3plote,np.abs(np.array(Bsec130_ll)/np.array(Bsec330_ll)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax5.plot(l3plote,np.abs(np.array(Bsec150_ll)/np.array(Bsec350_ll)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax5.plot(l3plote,np.abs(np.array(Bsec1100_ll)/np.array(Bsec3100_ll)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)


ax6.plot(l3ploto,np.abs(np.array(Bsec130_ll1)/np.array(Bsec330_ll1)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax6.plot(l3ploto,np.abs(np.array(Bsec150_ll1)/np.array(Bsec350_ll1)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax6.plot(l3ploto,np.abs(np.array(Bsec1100_ll1)/np.array(Bsec3100_ll1)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)


ax7.plot(l3plote,np.abs(np.array(Bsec130_ll)/np.array(Bsec430_ll)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax7.plot(l3plote,np.abs(np.array(Bsec150_ll)/np.array(Bsec450_ll)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax7.plot(l3plote,np.abs(np.array(Bsec1100_ll)/np.array(Bsec4100_ll)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)


ax8.plot(l3ploto,np.abs(np.array(Bsec130_ll1)/np.array(Bsec430_ll1)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax8.plot(l3ploto,np.abs(np.array(Bsec150_ll1)/np.array(Bsec450_ll1)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax8.plot(l3ploto,np.abs(np.array(Bsec1100_ll1)/np.array(Bsec4100_ll1)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)

plt.savefig("plots/match_terms_T.pdf", dpi=300, bbox_inches='tight')


plt.show()
plt.close()

# %%
# plot prim1/otherprim sec1/othersec <21-21-E>

fig, ((ax1,ax2),(ax3,ax4),(ax5,ax6),(ax7,ax8)) = plt.subplots(nrows=4, ncols=2, figsize=(9, 13))


fig.suptitle('Cross-correlation with E', fontsize=20,y=0.95)




fig.subplots_adjust(hspace=0.7)
fig.subplots_adjust(wspace=0.3)


ax1.set_title(r'$\ell_1 \simeq \ell_2 = 10^4 \qquad$ $ \ell_3=$ even', fontsize=18)
ax2.set_title(r'$\ell_1 \simeq \ell_2 = 10^4 \qquad$ $ \ell_3=$ odd', fontsize=18)



ax1.set_xlabel(r'$\ell_3$', fontsize=18)
ax2.set_xlabel(r'$\ell_3$', fontsize=18)

ax3.set_xlabel(r'$\ell_3$', fontsize=18)
ax4.set_xlabel(r'$\ell_3$', fontsize=18)

ax5.set_xlabel(r'$\ell_3$', fontsize=18)
ax6.set_xlabel(r'$\ell_3$', fontsize=18)

ax7.set_xlabel(r'$\ell_3$', fontsize=18)
ax8.set_xlabel(r'$\ell_3$', fontsize=18)





ax1.set_xlim(1,12)
ax2.set_xlim(1,12)
ax3.set_xlim(1,12)
ax4.set_xlim(1,12)
ax5.set_xlim(1,12)
ax6.set_xlim(1,12)
ax7.set_xlim(1,12)
ax8.set_xlim(1,12)




ax1.set_ylabel(r'$|B_{\ell_1 \ell_2 \ell_3}^{\rm prim, 1}/B_{\ell_1 \ell_2 \ell_3}^{\rm prim, 2}|$', fontsize=18)


ax3.set_ylabel(r'$|B_{\ell_1 \ell_2 \ell_3}^{\rm sec, 1}/B_{\ell_1 \ell_2 \ell_3}^{\rm sec, 2}|$', fontsize=18)


ax5.set_ylabel(r'$|B_{\ell_1 \ell_2 \ell_3}^{\rm sec, 1}/B_{\ell_1 \ell_2 \ell_3}^{\rm sec, 3}|$', fontsize=18)


ax7.set_ylabel(r'$|B_{\ell_1 \ell_2 \ell_3}^{\rm sec, 1}/B_{\ell_1 \ell_2 \ell_3}^{\rm sec, 4}|$', fontsize=18)



ax1.set_yscale('log')
ax2.set_yscale('log')
ax3.set_yscale('log')
ax4.set_yscale('log')
ax5.set_yscale('log')
ax6.set_yscale('log')
ax7.set_yscale('log')
ax8.set_yscale('log')

ax1.plot(l3plote,np.abs(np.array(Bprim30pol_ll)/np.array(Bprim230pol_ll)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax1.plot(l3plote,np.abs(np.array(Bprim50pol_ll)/np.array(Bprim250pol_ll)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax1.plot(l3plote,np.abs(np.array(Bprim100pol_ll)/np.array(Bprim2100pol_ll)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)


ax2.plot(l3ploto,np.abs(np.array(Bprim30pol_ll1)/np.array(Bprim230pol_ll1)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax2.plot(l3ploto,np.abs(np.array(Bprim50pol_ll1)/np.array(Bprim250pol_ll1)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax2.plot(l3ploto,np.abs(np.array(Bprim100pol_ll1)/np.array(Bprim2100pol_ll1)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)

ax2.legend(bbox_to_anchor=(1.3, 0.80), loc='center', ncol = 1, borderaxespad=0., fontsize=15)#(loc='best', fontsize=20)


ax3.plot(l3plote,np.abs(np.array(Bsec130pol_ll)/np.array(Bsec230pol_ll)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax3.plot(l3plote,np.abs(np.array(Bsec150pol_ll)/np.array(Bsec250pol_ll)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax3.plot(l3plote,np.abs(np.array(Bsec1100pol_ll)/np.array(Bsec2100pol_ll)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)


ax4.plot(l3ploto,np.abs(np.array(Bsec130pol_ll1)/np.array(Bsec230pol_ll1)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax4.plot(l3ploto,np.abs(np.array(Bsec150pol_ll1)/np.array(Bsec250pol_ll1)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax4.plot(l3ploto,np.abs(np.array(Bsec1100pol_ll1)/np.array(Bsec2100pol_ll1)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)


ax5.plot(l3plote,np.abs(np.array(Bsec130pol_ll)/np.array(Bsec330pol_ll)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax5.plot(l3plote,np.abs(np.array(Bsec150pol_ll)/np.array(Bsec350pol_ll)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax5.plot(l3plote,np.abs(np.array(Bsec1100pol_ll)/np.array(Bsec3100pol_ll)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)


ax6.plot(l3ploto,np.abs(np.array(Bsec130pol_ll1)/np.array(Bsec330pol_ll1)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax6.plot(l3ploto,np.abs(np.array(Bsec150pol_ll1)/np.array(Bsec350pol_ll1)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax6.plot(l3ploto,np.abs(np.array(Bsec1100pol_ll1)/np.array(Bsec3100pol_ll1)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)


ax7.plot(l3plote,np.abs(np.array(Bsec130pol_ll)/np.array(Bsec430pol_ll)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax7.plot(l3plote,np.abs(np.array(Bsec150pol_ll)/np.array(Bsec450pol_ll)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax7.plot(l3plote,np.abs(np.array(Bsec1100pol_ll)/np.array(Bsec4100pol_ll)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)


ax8.plot(l3ploto,np.abs(np.array(Bsec130pol_ll1)/np.array(Bsec430pol_ll1)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax8.plot(l3ploto,np.abs(np.array(Bsec150pol_ll1)/np.array(Bsec450pol_ll1)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax8.plot(l3ploto,np.abs(np.array(Bsec1100pol_ll1)/np.array(Bsec4100pol_ll1)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)






plt.savefig("plots/match_terms_E.pdf", dpi=300, bbox_inches='tight')


plt.show()
plt.close()

# %%
# plot prim/sec <21-21-E>

fig, ((ax1,ax7), (ax2,ax8), (ax3,ax9), (ax4,ax10), (ax5,ax11)) = plt.subplots(nrows=5, ncols=2, figsize=(9, 15))


fig.suptitle('Cross-correlation with E', fontsize=20,y=0.95)




fig.subplots_adjust(hspace=0.7)
fig.subplots_adjust(wspace=0.3)


ax1.set_title(r'$\ell_1 = \ell_2 \qquad$ $\ell_3=$ even', fontsize=18)
ax2.set_title(r'$\ell_1 = \ell_2+2 \qquad$ $\ell_3=$ even', fontsize=18)
ax3.set_title(r'$\ell_1 = \ell_2+4 \qquad$ $\ell_3=$ even', fontsize=18)
ax4.set_title(r'$\ell_1 = \ell_2+6 \qquad$ $\ell_3=$ even', fontsize=18)
ax5.set_title(r'$\ell_1 = \ell_2+8 \qquad$ $\ell_3=$ even', fontsize=18)

ax7.set_title(r'$\ell_1 = \ell_2+1 \qquad$ $\ell_3=$ odd', fontsize=18)
ax8.set_title(r'$\ell_1 = \ell_2+3 \qquad$ $\ell_3=$ odd', fontsize=18)
ax9.set_title(r'$\ell_1 = \ell_2+5 \qquad$ $\ell_3=$ odd', fontsize=18)
ax10.set_title(r'$\ell_1 = \ell_2+7 \qquad$ $\ell_3=$ odd', fontsize=18)
ax11.set_title(r'$\ell_1 = \ell_2+9 \qquad$ $\ell_3=$ odd', fontsize=18)


ax1.set_xlabel(r'$\ell_3$', fontsize=18)
ax2.set_xlabel(r'$\ell_3$', fontsize=18)
ax3.set_xlabel(r'$\ell_3$', fontsize=18)
ax4.set_xlabel(r'$\ell_3$', fontsize=18)
ax5.set_xlabel(r'$\ell_3$', fontsize=18)

ax7.set_xlabel(r'$\ell_3$', fontsize=18)
ax8.set_xlabel(r'$\ell_3$', fontsize=18)
ax9.set_xlabel(r'$\ell_3$', fontsize=18)
ax10.set_xlabel(r'$\ell_3$', fontsize=18)
ax11.set_xlabel(r'$\ell_3$', fontsize=18)



ax1.set_xlim(1,12)
ax2.set_xlim(1,12)
ax3.set_xlim(1,12)
ax4.set_xlim(1,12)
ax5.set_xlim(1,12)

ax7.set_xlim(1,12)
ax8.set_xlim(1,12)
ax9.set_xlim(1,12)
ax10.set_xlim(1,12)
ax11.set_xlim(1,12)



ax1.set_ylabel(r'$|B_{\ell_1 \ell_2 \ell_3}^{\rm prim}/B_{\ell_1 \ell_2 \ell_3}^{\rm sec}|$', fontsize=18)
ax2.set_ylabel(r'$|B_{\ell_1 \ell_2 \ell_3}^{\rm prim}/B_{\ell_1 \ell_2 \ell_3}^{\rm sec}|$', fontsize=18)
ax3.set_ylabel(r'$|B_{\ell_1 \ell_2 \ell_3}^{\rm prim}/B_{\ell_1 \ell_2 \ell_3}^{\rm sec}|$', fontsize=18)
ax4.set_ylabel(r'$|B_{\ell_1 \ell_2 \ell_3}^{\rm prim}/B_{\ell_1 \ell_2 \ell_3}^{\rm sec}|$', fontsize=18)
ax5.set_ylabel(r'$|B_{\ell_1 \ell_2 \ell_3}^{\rm prim}/B_{\ell_1 \ell_2 \ell_3}^{\rm sec}|$', fontsize=18)

ax1.set_yscale('log')
ax2.set_yscale('log')
ax3.set_yscale('log')
ax4.set_yscale('log')
ax5.set_yscale('log')

ax7.set_yscale('log')
ax8.set_yscale('log')
ax9.set_yscale('log')
ax10.set_yscale('log')
ax11.set_yscale('log')


ax1.plot(l3plote,np.abs(np.array(Bprim30pol_ll)/np.array(Bsec30pol_ll)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax1.plot(l3plote,np.abs(np.array(Bprim50pol_ll)/np.array(Bsec50pol_ll)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax1.plot(l3plote,np.abs(np.array(Bprim100pol_ll)/np.array(Bsec100pol_ll)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)



ax2.plot(l3plote,np.abs(np.array(Bprim30pol_ll2)/np.array(Bsec30pol_ll2)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax2.plot(l3plote,np.abs(np.array(Bprim50pol_ll2)/np.array(Bsec50pol_ll2)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax2.plot(l3plote,np.abs(np.array(Bprim100pol_ll2)/np.array(Bsec100pol_ll2)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)

ax3.plot(l3plote[1:],np.abs(np.array(Bprim30pol_ll4)[1:]/np.array(Bsec30pol_ll4)[1:]),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax3.plot(l3plote[1:],np.abs(np.array(Bprim50pol_ll4)[1:]/np.array(Bsec50pol_ll4)[1:]),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax3.plot(l3plote[1:],np.abs(np.array(Bprim100pol_ll4)[1:]/np.array(Bsec100pol_ll4)[1:]),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)

ax4.plot(l3plote[2:],np.abs(np.array(Bprim30pol_ll6)[2:]/np.array(Bsec30pol_ll6)[2:]),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax4.plot(l3plote[2:],np.abs(np.array(Bprim50pol_ll6)[2:]/np.array(Bsec50pol_ll6)[2:]),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax4.plot(l3plote[2:],np.abs(np.array(Bprim100pol_ll6)[2:]/np.array(Bsec100pol_ll6)[2:]),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)

ax5.plot(l3plote[3:],np.abs(np.array(Bprim30pol_ll8)[3:]/np.array(Bsec30pol_ll8)[3:]),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax5.plot(l3plote[3:],np.abs(np.array(Bprim50pol_ll8)[3:]/np.array(Bsec50pol_ll8)[3:]),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax5.plot(l3plote[3:],np.abs(np.array(Bprim100pol_ll8)[3:]/np.array(Bsec100pol_ll8)[3:]),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)




ax7.plot(l3ploto,np.abs(np.array(Bprim30pol_ll1)/np.array(Bsec30pol_ll1)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax7.plot(l3ploto,np.abs(np.array(Bprim50pol_ll1)/np.array(Bsec50pol_ll1)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax7.plot(l3ploto,np.abs(np.array(Bprim100pol_ll1)/np.array(Bsec100pol_ll1)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)

ax7.legend(bbox_to_anchor=(1.3, 0.80), loc='center', ncol = 1, borderaxespad=0., fontsize=15)#(loc='best', fontsize=20)



ax8.plot(l3ploto,np.abs(np.array(Bprim30pol_ll3)/np.array(Bsec30pol_ll3)),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax8.plot(l3ploto,np.abs(np.array(Bprim50pol_ll3)/np.array(Bsec50pol_ll3)),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax8.plot(l3ploto,np.abs(np.array(Bprim100pol_ll3)/np.array(Bsec100pol_ll3)),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)

ax9.plot(l3ploto[1:],np.abs(np.array(Bprim30pol_ll5)[1:]/np.array(Bsec30pol_ll5)[1:]),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax9.plot(l3ploto[1:],np.abs(np.array(Bprim50pol_ll5)[1:]/np.array(Bsec50pol_ll5)[1:]),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax9.plot(l3ploto[1:],np.abs(np.array(Bprim100pol_ll5)[1:]/np.array(Bsec100pol_ll5)[1:]),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)

ax10.plot(l3ploto[2:],np.abs(np.array(Bprim30pol_ll7)[2:]/np.array(Bsec30pol_ll7)[2:]),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax10.plot(l3ploto[2:],np.abs(np.array(Bprim50pol_ll7)[2:]/np.array(Bsec50pol_ll7)[2:]),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax10.plot(l3ploto[2:],np.abs(np.array(Bprim100pol_ll7)[2:]/np.array(Bsec100pol_ll7)[2:]),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)

ax11.plot(l3ploto[3:],np.abs(np.array(Bprim30pol_ll9)[3:]/np.array(Bsec30pol_ll9)[3:]),'o', label = r'$z=30$', color = 'royalblue',markersize=4)
ax11.plot(l3ploto[3:],np.abs(np.array(Bprim50pol_ll9)[3:]/np.array(Bsec50pol_ll9)[3:]),'o', label = r'$z=50$', color = 'darkorange',markersize=4)
ax11.plot(l3ploto[3:],np.abs(np.array(Bprim100pol_ll9)[3:]/np.array(Bsec100pol_ll9)[3:]),'o', label = r'$z=100$', color = 'darkgreen',markersize=4)


plt.savefig("plots/prims_vs_secpol.pdf", dpi=300, bbox_inches='tight')


plt.show()
plt.close()

# %% [markdown]
# ## PS, flat-sky exact vs full-sky Limber

# %%
# list of l for plot

llistpl = np.logspace(1,5,100)

# %%
# 21-cm PS exact flat sky

def c21(i,r,z,dnu):
    l= int(llistpl[i])
    
    if z == 30:
        integrand = lambda q: Wq(q,z,dnu)**2*trans(q,l,r,z)**2*(mono30f(np.sqrt(q**2+l**2/r**2)))**2*scalarpower(np.sqrt(q**2+l**2/r**2))
    elif z == 50:
        integrand = lambda q: Wq(q,z,dnu)**2*trans(q,l,r,z)**2*(mono50f(np.sqrt(q**2+l**2/r**2)))**2*scalarpower(np.sqrt(q**2+l**2/r**2))
    elif z == 100:
        integrand = lambda q: Wq(q,z,dnu)**2*trans(q,l,r,z)**2*(mono100f(np.sqrt(q**2+l**2/r**2)))**2*scalarpower(np.sqrt(q**2+l**2/r**2))
    
    inte = scint.quad(integrand,1e-5,200.,epsabs=0.,epsrel=1e-4, limit = 10000000)[0]
    factor = l**2/(2*np.pi)
    value = inte*factor/r**2/(2*np.pi)
    return value

# %%
# y-sampling for 21-cm PS computation- full sky Limber 

def Limber21_c21_30(l):
    value = y30*W(r30,y30,30,0.1)**2*mono30f(l/y30)**2*alp1r(y30)**2*scal_pow(l/y30)
    return value   

def Limber21_c21_50(l):
    value = y50*W(r50,y50,50,0.1)**2*mono50f(l/y50)**2*alp1r(y50)**2*scal_pow(l/y50)
    return value   

def Limber21_c21_100(l):
    value = y100*W(r100,y100,100,0.1)**2*mono100f(l/y100)**2*alp1r(y100)**2*scal_pow(l/y100)
    return value   

# y-sampling for 21-cm PS computation- full sky Limber - Deltaw = 1 MHz case  

def Limber21_c21_30_1Mhz(l):
    value = y301*W(r30,y301,30,1)**2*mono30f(l/y301)**2*alp1r(y301)**2*scal_pow(l/y301)
    return value   

def Limber21_c21_50_1Mhz(l):
    value = y501*W(r50,y501,50,1)**2*mono50f(l/y501)**2*alp1r(y501)**2*scal_pow(l/y501)
    return value   

def Limber21_c21_100_1Mhz(l):
    value = y1001*W(r100,y1001,100,1)**2*mono100f(l/y1001)**2*alp1r(y1001)**2*scal_pow(l/y1001)
    return value

# %%
# 21-cm PS, limber+no velocity terms, for Fisher forecasts

def c21_30(i,r,z,dnu):
    l= int(llist2[i])
    cms = Limber21_c21_30(l)
    I2= integrate.simps(cms,x=y30)
    factor = 2*np.pi**2/l**3
    value = I2*factor
    return value

def c21_50(i,r,z,dnu):
    l= int(llist2[i])
    cms = Limber21_c21_50(l)
    I2= integrate.simps(cms,x=y50)
    factor = 2*np.pi**2/l**3
    value = I2*factor
    return value

def c21_100(i,r,z,dnu):
    l= int(llist2[i])
    cms = Limber21_c21_100(l)
    I2= integrate.simps(cms,x=y100)
    factor = 2*np.pi**2/l**3
    value = I2*factor
    return value

# %%
# 21-cm PS, limber+no velocity terms for plot

def c21_30plt(i,r,z,dnu):
    l= int(llistpl[i])
    cms = Limber21_c21_30(l)
    I2= integrate.simps(cms,x=y30)
    factor = 2*np.pi**2/l**3
    value = I2*factor
    return value

def c21_50plt(i,r,z,dnu):
    l= int(llistpl[i])
    cms = Limber21_c21_50(l)
    I2= integrate.simps(cms,x=y50)
    factor = 2*np.pi**2/l**3
    value = I2*factor
    return value

def c21_100plt(i,r,z,dnu):
    l= int(llistpl[i])
    cms = Limber21_c21_100(l)
    I2= integrate.simps(cms,x=y100)
    factor = 2*np.pi**2/l**3
    value = I2*factor
    return value


# 21-cm PS, limber+no velocity terms for plot - Deltaw = 1 MHz case 

def c21_30plt1(i,r,z,dnu):
    l= int(llistpl[i])
    cms = Limber21_c21_30_1Mhz(l)
    I2= integrate.simps(cms,x=y301)
    factor = 2*np.pi**2/l**3
    value = I2*factor
    return value

def c21_50plt1(i,r,z,dnu):
    l= int(llistpl[i])
    cms = Limber21_c21_50_1Mhz(l)
    I2= integrate.simps(cms,x=y501)
    factor = 2*np.pi**2/l**3
    value = I2*factor
    return value

def c21_100plt1(i,r,z,dnu):
    l= int(llistpl[i])
    cms = Limber21_c21_100_1Mhz(l)
    I2= integrate.simps(cms,x=y1001)
    factor = 2*np.pi**2/l**3
    value = I2*factor
    return value

# %%
# 21-cm PS computation, limber+no vel z=30, for Fisher-Forecast

C21r30w01=np.array([c21_30(i,r30,30,0.1) for i in range(len(llist2))])

# %%
# 21-cm PS computation, limber+no vel z=50, for Fisher-Forecast
C21r50w01=np.array([c21_50(i,r50,50,0.1) for i in range(len(llist2))])

# %%
# 21-cm PS computation, limber+no vel z=100, for Fisher-Forecast

C21r100w01=np.array([c21_100(i,r100,100,0.1) for i in range(len(llist2))])

# %%
# 21-cm PS Limber Delta_nu = 0.1 

C21r30w01plt=[np.sqrt(c21_30plt(i,r30,30,0.1)*llistpl[i]**2/(2*np.pi)) for i in range(len(llistpl))]
C21r50w01plt=[np.sqrt(c21_50plt(i,r50,50,0.1)*llistpl[i]**2/(2*np.pi)) for i in range(len(llistpl))]
C21r100w01plt=[np.sqrt(c21_100plt(i,r100,100,0.1)*llistpl[i]**2/(2*np.pi)) for i in range(len(llistpl))]

# %%
# 21-cm PS Limber Delta_nu = 1 

C21r30w1plt=[np.sqrt(c21_30plt1(i,r30,30,1)*llistpl[i]**2/(2*np.pi)) for i in range(len(llistpl))]
C21r50w1plt=[np.sqrt(c21_50plt1(i,r50,50,1)*llistpl[i]**2/(2*np.pi)) for i in range(len(llistpl))]
C21r100w1plt=[np.sqrt(c21_100plt1(i,r100,100,1)*llistpl[i]**2/(2*np.pi)) for i in range(len(llistpl))]

# %%
# 21-cm PS exact z = 30

C21r3001=[np.sqrt(c21(i,r30,30.,0.1)) for i in range(len(llistpl))]
C21r301=[np.sqrt(c21(i,r30,30.,1.)) for i in range(len(llistpl))]
C21r300=[np.sqrt(c21(i,r30,30.,0.)) for i in range(len(llistpl))]

# %%
# 21-cm PS exact z = 50

C21r5001=[np.sqrt(c21(i,r50,50.,0.1)) for i in range(len(llistpl))]
C21r501=[np.sqrt(c21(i,r50,50.,1.)) for i in range(len(llistpl))]
C21r500=[np.sqrt(c21(i,r50,50.,0.)) for i in range(len(llistpl))]

# %%
# 21-cm PS exact z = 100

C21r10001=[np.sqrt(c21(i,r100,100.,0.1)) for i in range(len(llistpl))]
C21r1001=[np.sqrt(c21(i,r100,100.,1.)) for i in range(len(llistpl))]
C21r1000=[np.sqrt(c21(i,r100,100.,0.)) for i in range(len(llistpl))]

# %%
# for plots

def kplot(x):
    value = x/r50
    return value

def invkplot(x):
    value = x*r50
    return value

# %%
# plot 21-cm PS exact vs limber $\Delta \nu = 0.1 \,$ MHz

fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2,figsize=(15, 5))

fig.subplots_adjust(wspace=0.15)

ax1.set_xscale('log')

ax1.set_yscale('log')

ax2.set_xscale('log')

ax2.set_yscale('log')



# ax1.plot(llistpl,C21r3001_novel, label = '$z=30$', color = 'royalblue', linewidth = 2.5, linestyle = ':', zorder = 10)
ax1.plot(llistpl,C21r3001, label = '$z=30$', color = 'royalblue', linewidth = 2.5, linestyle = '-', zorder = 10)
ax1.plot(llistpl,C21r30w01plt, color = 'royalblue', linewidth = 2.5, linestyle = '--', zorder = 10)

# ax1.plot(llistpl,C21r5001_novel, color = 'green', linewidth = 2.5, linestyle = ':', zorder = 10)
ax1.plot(llistpl,C21r5001, label = '$z=50$', color = 'green', linewidth = 2.5, linestyle = '-', zorder = 10)
ax1.plot(llistpl,C21r50w01plt, color = 'green', linewidth = 2.5, linestyle = '--', zorder = 10)

# ax1.plot(llistpl,C21r10001_novel, color = 'red', linewidth = 2.5, linestyle = ':', zorder = 10)
ax1.plot(llistpl,C21r10001, label = '$z=100$', color = 'red', linewidth = 2.5, linestyle = '-', zorder = 10)
ax1.plot(llistpl,C21r100w01plt, color = 'red', linewidth = 2.5, linestyle = '--', zorder = 10)



# ax2.plot(llistpl,C21r301_novel, label = '$z=30$', color = 'royalblue', linewidth = 2.5, linestyle = ':', zorder = 10)
ax2.plot(llistpl,C21r301, label = '$z=30$', color = 'royalblue', linewidth = 2.5, linestyle = '-', zorder = 10)
ax2.plot(llistpl,C21r30w1plt, color = 'royalblue', linewidth = 2.5, linestyle = '--', zorder = 10)

# ax2.plot(llistpl,C21r5001_novel, color = 'green', linewidth = 2.5, linestyle = ':', zorder = 10)
ax2.plot(llistpl,C21r501, label = '$z=50$', color = 'green', linewidth = 2.5, linestyle = '-', zorder = 10)
ax2.plot(llistpl,C21r50w1plt, color = 'green', linewidth = 2.5, linestyle = '--', zorder = 10)

# ax2.plot(llistpl,C21r1001_novel, color = 'red', linewidth = 2.5, linestyle = ':', zorder = 10)
ax2.plot(llistpl,C21r1001, label = '$z=100$', color = 'red', linewidth = 2.5, linestyle = '-', zorder = 10)
ax2.plot(llistpl,C21r100w1plt, color = 'red', linewidth = 2.5, linestyle = '--', zorder = 10)

ax1.set_xlim(1e2,1e5)
ax2.set_xlim(1e2,1e5)

ax1.set_ylim(1e-1,1)
ax2.set_ylim(3e-2,4e-1)


ax1.set_xlabel(r'$\ell$', fontsize=25)
ax2.set_xlabel(r'$\ell$', fontsize=25)

ax1.set_ylabel(r'$(C_\ell \, \ell^2/2\pi)^{1/2} \, $  [mK]', fontsize=20)
ax2.legend(loc='best',fontsize=18)#(loc='best', fontsize=20)

ax1.set_title(r'$\Delta \nu = 0.1 \,$ MHz', fontsize=20)

ax2.set_title(r'$\Delta \nu = 1 \,$ MHz', fontsize=20)

ax1.tick_params(labelsize=15)
ax2.tick_params(labelsize=15)

ax1.grid(True, which='both',linestyle='--', alpha = 0.4)
ax2.grid(True, which='both',linestyle='--', alpha = 0.4)


ax3 = ax1.secondary_xaxis("top",functions=(kplot,invkplot))
ax3.set_xlabel(r'$k \,\, [Mpc^{-1}]$', fontsize=15, loc="right")
ax3.tick_params(labelsize=15)

ax4 = ax2.secondary_xaxis("top",functions=(kplot,invkplot))
ax4.set_xlabel(r'$k \,\, [Mpc^{-1}]$', fontsize=15, loc="right")
ax4.tick_params(labelsize=15)

plt.savefig("plots/21cm_power.pdf", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Fisher matrix forecasts, SNR's

# %%
# Fisher terms 21-21-T, z=30

def Fisher_T_30(l1,l2,l3):
    D = 1
    if l1 == l2:
        D=2
    B1 = B_prim_I1_T_30(l1,l2,l3)
    B2 = B_sec_I1_T_30(l1,l2,l3)
    B3 = 0
    if l3%2==1:
        B3 += B_sec_I2_T_30(l1,l2,l3)
    C = C21r30w01[l1-10000]*C21r30w01[l2-10000]*cTTspectra[l3-2]*D
    fish1 = B1**2 / C
    fish2 = B2**2 / C
    fish3 = B3**2 / C
    fish12= B1*B2 / C
    fish13= B1*B3 / C
    fish23= B2*B3 / C
    
    return fish1, fish2, fish12, fish3, fish13, fish23


# Fisher terms 21-21-T, z=50

def Fisher_T_50(l1,l2,l3):
    D = 1
    if l1 == l2:
        D=2
    B1 = B_prim_I1_T_50(l1,l2,l3)
    B2 = B_sec_I1_T_50(l1,l2,l3)
    B3 = 0
    if l3%2==1:
        B3 += B_sec_I2_T_50(l1,l2,l3)
    C = C21r50w01[l1-10000]*C21r50w01[l2-10000]*cTTspectra[l3-2]*D
    fish1 = B1**2 / C
    fish2 = B2**2 / C
    fish3 = B3**2 / C
    fish12= B1*B2 / C
    fish13= B1*B3 / C
    fish23= B2*B3 / C
    return fish1, fish2, fish12, fish3, fish13, fish23


# Fisher terms 21-21-T, z=100

def Fisher_T_100(l1,l2,l3):
    D = 1
    if l1 == l2:
        D=2
    B1 = B_prim_I1_T_100(l1,l2,l3)
    B2 = B_sec_I1_T_100(l1,l2,l3)
    B3 = 0
    if l3%2==1:
        B3 += B_sec_I2_T_100(l1,l2,l3)
    C = C21r100w01[l1-10000]*C21r100w01[l2-10000]*cTTspectra[l3-2]*D
    fish1 = B1**2 / C
    fish2 = B2**2 / C
    fish3 = B3**2 / C
    fish12= B1*B2 / C
    fish13= B1*B3 / C
    fish23= B2*B3 / C
    return fish1, fish2, fish12, fish3, fish13, fish23

# %%
# Fisher terms 21-21-T + 21-21-E, z=30

def Fisher_TE_30(l1,l2,l3): 
    D = 1
    if l1 == l2:
        D=2
        
    B1_T = B_prim_I1_T_30(l1,l2,l3)
    B1_E = B_prim_I1_E_30(l1,l2,l3)

    B2_T = B_sec_I1_T_30(l1,l2,l3)
    B2_E = B_sec_I1_E_30(l1,l2,l3)
    
    B3_T = 0
    B3_E = 0
    
    if l3%2==1:
        B3_T += B_sec_I2_T_30(l1,l2,l3)
        B3_E += B_sec_I2_E_30(l1,l2,l3)

    cterm = (cTTspectra[l3-2]*cEEspectra[l3-2]-cETspectra[l3-2]**2)
    CTT = C21r30w01[l1-10000]*C21r30w01[l2-10000]*cterm*D / cEEspectra[l3-2]
    CEE = C21r30w01[l1-10000]*C21r30w01[l2-10000]*cterm*D / cTTspectra[l3-2]
    CET = C21r30w01[l1-10000]*C21r30w01[l2-10000]*cterm*D / cETspectra[l3-2]
    
    fish1 = B1_T**2 / CTT
    fish1+= B1_E**2 / CEE
    fish1+= -2*B1_T*B1_E / CET

    fish2 = B2_T**2 / CTT
    fish2+= B2_E**2 / CEE
    fish2+= -2*B2_T*B2_E / CET
    
    fish3 = B3_T**2 / CTT
    fish3+= B3_E**2 / CEE
    fish3+= -2*B3_T*B3_E / CET

    fish12 = B1_T*B2_T / CTT
    fish12+= B1_E*B2_E / CEE
    fish12+= -B1_T*B2_E / CET
    fish12+= -B1_E*B2_T / CET
    
    fish13 = B1_T*B3_T / CTT
    fish13+= B1_E*B3_E / CEE
    fish13+= -B1_T*B3_E / CET
    fish13+= -B1_E*B3_T / CET
    
    fish23 = B2_T*B3_T / CTT
    fish23+= B2_E*B3_E / CEE
    fish23+= -B2_T*B3_E / CET
    fish23+= -B2_E*B3_T / CET
    
    return fish1, fish2, fish12, fish3, fish13, fish23

# Fisher terms 21-21-T + 21-21-E, z=50

def Fisher_TE_50(l1,l2,l3): 
    D = 1
    if l1 == l2:
        D=2
        
    B1_T = B_prim_I1_T_50(l1,l2,l3)
    B1_E = B_prim_I1_E_50(l1,l2,l3)

    B2_T = B_sec_I1_T_50(l1,l2,l3)
    B2_E = B_sec_I1_E_50(l1,l2,l3)
    
    B3_T = 0
    B3_E = 0
    
    if l3%2==1:
        B3_T += B_sec_I2_T_50(l1,l2,l3)
        B3_E += B_sec_I2_E_50(l1,l2,l3)

    cterm = (cTTspectra[l3-2]*cEEspectra[l3-2]-cETspectra[l3-2]**2)
    CTT = C21r50w01[l1-10000]*C21r50w01[l2-10000]*cterm*D / cEEspectra[l3-2]
    CEE = C21r50w01[l1-10000]*C21r50w01[l2-10000]*cterm*D / cTTspectra[l3-2]
    CET = C21r50w01[l1-10000]*C21r50w01[l2-10000]*cterm*D / cETspectra[l3-2]
    
    fish1 = B1_T**2 / CTT
    fish1+= B1_E**2 / CEE
    fish1+= -2*B1_T*B1_E / CET

    fish2 = B2_T**2 / CTT
    fish2+= B2_E**2 / CEE
    fish2+= -2*B2_T*B2_E / CET

    fish3 = B3_T**2 / CTT
    fish3+= B3_E**2 / CEE
    fish3+= -2*B3_T*B3_E / CET

    fish12 = B1_T*B2_T / CTT
    fish12+= B1_E*B2_E / CEE
    fish12+= -B1_T*B2_E / CET
    fish12+= -B1_E*B2_T / CET
    
    fish13 = B1_T*B3_T / CTT
    fish13+= B1_E*B3_E / CEE
    fish13+= -B1_T*B3_E / CET
    fish13+= -B1_E*B3_T / CET
    
    fish23 = B2_T*B3_T / CTT
    fish23+= B2_E*B3_E / CEE
    fish23+= -B2_T*B3_E / CET
    fish23+= -B2_E*B3_T / CET
    
    return fish1, fish2, fish12, fish3, fish13, fish23

# Fisher terms 21-21-T + 21-21-E, z=100

def Fisher_TE_100(l1,l2,l3): 
    D = 1
    if l1 == l2:
        D=2
        
    B1_T = B_prim_I1_T_100(l1,l2,l3)
    B1_E = B_prim_I1_E_100(l1,l2,l3)

    B2_T = B_sec_I1_T_100(l1,l2,l3)
    B2_E = B_sec_I1_E_100(l1,l2,l3)
    
    B3_T = 0
    B3_E = 0
    
    if l3%2==1:
        B3_T += B_sec_I2_T_100(l1,l2,l3)
        B3_E += B_sec_I2_E_100(l1,l2,l3)

    cterm = (cTTspectra[l3-2]*cEEspectra[l3-2]-cETspectra[l3-2]**2)
    CTT = C21r100w01[l1-10000]*C21r100w01[l2-10000]*cterm*D / cEEspectra[l3-2]
    CEE = C21r100w01[l1-10000]*C21r100w01[l2-10000]*cterm*D / cTTspectra[l3-2]
    CET = C21r100w01[l1-10000]*C21r100w01[l2-10000]*cterm*D / cETspectra[l3-2]
    
    fish1 = B1_T**2 / CTT
    fish1+= B1_E**2 / CEE
    fish1+= -2*B1_T*B1_E / CET

    fish2 = B2_T**2 / CTT
    fish2+= B2_E**2 / CEE
    fish2+= -2*B2_T*B2_E / CET

    fish3 = B3_T**2 / CTT
    fish3+= B3_E**2 / CEE
    fish3+= -2*B3_T*B3_E / CET

    fish12 = B1_T*B2_T / CTT
    fish12+= B1_E*B2_E / CEE
    fish12+= -B1_T*B2_E / CET
    fish12+= -B1_E*B2_T / CET
    
    fish13 = B1_T*B3_T / CTT
    fish13+= B1_E*B3_E / CEE
    fish13+= -B1_T*B3_E / CET
    fish13+= -B1_E*B3_T / CET
    
    fish23 = B2_T*B3_T / CTT
    fish23+= B2_E*B3_E / CEE
    fish23+= -B2_T*B3_E / CET
    fish23+= -B2_E*B3_T / CET
    
    return fish1, fish2, fish12, fish3, fish13, fish23

# %%
# FISHER DEFINITION 


def Fisher_l3(Fisher,l3,llist2):
    # wig.wig_table_free()
    # wig.wig_temp_free()
    wig.wig_table_init(140002,3)
    wig.wig_temp_init(140002)
    val = np.zeros((len(llist2),3,3))
    for i1 in tqdm(range(len(llist2)),disable=(l3!=l3list[-1])):
    # for i1 in tqdm(range(len(llist2))):
        l1 = llist2[i1]
        # l2list = np.arange(l1,np.fmin(l1+l3,llist2[-1])+1)
        l2list = np.arange(np.fmax(l1-l3,llist2[0]),l1+1)
        for l2 in l2list:
            if (l2+l1+l3) % 2== 0:
                fishy = Fisher(l2,l1,l3) 
                val[i1,0,0] += fishy[0]
                val[i1,1,1] += fishy[1]
                val[i1,0,1] += fishy[2]
                val[i1,2,2] += fishy[3]
                val[i1,0,2] += fishy[4]
                val[i1,1,2] += fishy[5]
    wig.wig_table_free()
    wig.wig_temp_free()
    val[:,1,0] = val[:,0,1]
    val[:,2,0] = val[:,0,2]
    val[:,2,1] = val[:,1,2]
    return val.cumsum(0)

# %%
llist2 = np.arange(10000,100001)

# %%
# FISHER T COMPUTE 

FisherInfo_T_30 = np.array(Parallel(n_jobs=5,verbose=0)([delayed(Fisher_l3)(Fisher_T_30,l3,llist2) for l3 in l3list][::-1]))[::-1].cumsum(0)
FisherInfo_T_50 = np.array(Parallel(n_jobs=5,verbose=0)([delayed(Fisher_l3)(Fisher_T_50,l3,llist2) for l3 in l3list][::-1]))[::-1].cumsum(0)
FisherInfo_T_100 = np.array(Parallel(n_jobs=5,verbose=0)([delayed(Fisher_l3)(Fisher_T_100,l3,llist2) for l3 in l3list][::-1]))[::-1].cumsum(0)
# Out:
# 100%|██████████| 90001/90001 [35:56<00:00, 41.74it/s]
#  70%|███████   | 63142/90001 [24:58<10:57, 40.82it/s]

# %%
# FISHER T, SAVE

np.save(f"output_data/FisherInfo_T_40_l3max{l3list[-1]}_l1max{llist2[-1]}",FisherInfo_T_30)
np.save(f"output_data/FisherInfo_T_60_l3max{l3list[-1]}_l1max{llist2[-1]}",FisherInfo_T_50)
np.save(f"output_data/FisherInfo_T_80_l3max{l3list[-1]}_l1max{llist2[-1]}",FisherInfo_T_100)

# %%
# FISHER T+E COMPUTE 

FisherInfo_TE_30 = np.array(Parallel(n_jobs=5,verbose=0)([delayed(Fisher_l3)(Fisher_TE_30,l3,llist2) for l3 in l3list][::-1]))[::-1].cumsum(0)
FisherInfo_TE_50 = np.array(Parallel(n_jobs=5,verbose=0)([delayed(Fisher_l3)(Fisher_TE_50,l3,llist2) for l3 in l3list][::-1]))[::-1].cumsum(0)
FisherInfo_TE_100 = np.array(Parallel(n_jobs=5,verbose=0)([delayed(Fisher_l3)(Fisher_TE_100,l3,llist2) for l3 in l3list][::-1]))[::-1].cumsum(0)
# Out:
# 100%|██████████| 90001/90001 [1:18:23<00:00, 19.14it/s]

# %%
# FISHER T+E, SAVE

np.save(f"output_data/FisherInfo_TE_40_l3max{l3list[-1]}_l1max{llist2[-1]}",FisherInfo_TE_30)
np.save(f"output_data/FisherInfo_TE_60_l3max{l3list[-1]}_l1max{llist2[-1]}",FisherInfo_TE_50)
np.save(f"output_data/FisherInfo_TE_80_l3max{l3list[-1]}_l1max{llist2[-1]}",FisherInfo_TE_100)

# %%
# LOADING FISHER FORECASTS T and T+E AT DIFFERENT REDSHIFTS

FisherInfo_T_30 = np.load(f"output_data/FisherInfo_T_30_l3max{l3list[-1]}_l1max{llist2[-1]}.npy")
FisherInfo_T_40 = np.load(f"output_data/FisherInfo_T_40_l3max{l3list[-1]}_l1max{llist2[-1]}.npy")
FisherInfo_T_50 = np.load(f"output_data/FisherInfo_T_50_l3max{l3list[-1]}_l1max{llist2[-1]}.npy")
FisherInfo_T_60 = np.load(f"output_data/FisherInfo_T_60_l3max{l3list[-1]}_l1max{llist2[-1]}.npy")
FisherInfo_T_80 = np.load(f"output_data/FisherInfo_T_80_l3max{l3list[-1]}_l1max{llist2[-1]}.npy")
FisherInfo_T_100 = np.load(f"output_data/FisherInfo_T_100_l3max{l3list[-1]}_l1max{llist2[-1]}.npy")

FisherInfo_TE_30 = np.load(f"output_data/FisherInfo_TE_30_l3max{l3list[-1]}_l1max{llist2[-1]}.npy")
FisherInfo_TE_40 = np.load(f"output_data/FisherInfo_TE_40_l3max{l3list[-1]}_l1max{llist2[-1]}.npy")
FisherInfo_TE_50 = np.load(f"output_data/FisherInfo_TE_50_l3max{l3list[-1]}_l1max{llist2[-1]}.npy")
FisherInfo_TE_60 = np.load(f"output_data/FisherInfo_TE_60_l3max{l3list[-1]}_l1max{llist2[-1]}.npy")
FisherInfo_TE_80 = np.load(f"output_data/FisherInfo_TE_80_l3max{l3list[-1]}_l1max{llist2[-1]}.npy")
FisherInfo_TE_100 = np.load(f"output_data/FisherInfo_TE_100_l3max{l3list[-1]}_l1max{llist2[-1]}.npy")

# %% [markdown]
# # SNR ESTIMATED IN AN APPROXIMATED WAY

# %%
# SNR computed with approximated formula 42 of the paper

def SNR30(l3list):
    SNR = np.zeros(len(l3list))
    for i3 in range(len(l3list)):
        if l3list[i3] == 2 or l3list[i3] == 3:
            N = 2
        if l3list[i3] == 4 or l3list[i3] == 5:
            N = 3
        if l3list[i3] == 6 or l3list[i3] == 7:
            N = 4
        if l3list[i3] == 8 or l3list[i3] == 9:
            N = 5
        if l3list[i3] == 10 or l3list[i3] == 11:
            N = 6
        SNR[i3] =  SNR[i3-1] + R30T[i3]*N
    SNR = 9.5e5*np.sqrt(SNR)*(llist2[-1]/1e5)
    return SNR

def SNR50(l3list):
    SNR = np.zeros(len(l3list))
    for i3 in range(len(l3list)):
        if l3list[i3] == 2 or l3list[i3] == 3:
            N = 2
        if l3list[i3] == 4 or l3list[i3] == 5:
            N = 3
        if l3list[i3] == 6 or l3list[i3] == 7:
            N = 4
        if l3list[i3] == 8 or l3list[i3] == 9:
            N = 5
        if l3list[i3] == 10 or l3list[i3] == 11:
            N = 6
        SNR[i3] =  SNR[i3-1] + R50T[i3]*N
    SNR = 9.5e5*np.sqrt(SNR)*(llist2[-1]/1e5)
    return SNR

def SNR100(l3list):
    SNR = np.zeros(len(l3list))
    for i3 in range(len(l3list)):
        if l3list[i3] == 2 or l3list[i3] == 3:
            N = 2
        if l3list[i3] == 4 or l3list[i3] == 5:
            N = 3
        if l3list[i3] == 6 or l3list[i3] == 7:
            N = 4
        if l3list[i3] == 8 or l3list[i3] == 9:
            N = 5
        if l3list[i3] == 10 or l3list[i3] == 11:
            N = 6
        SNR[i3] =  SNR[i3-1] + R100T[i3]*N
    SNR = 9.5e5*np.sqrt(SNR)*(llist2[-1]/1e5)
    return SNR

snr30 = SNR30(l3list)
snr50 = SNR50(l3list)
snr100 = SNR100(l3list)

# %% [markdown]
# # Plots Delta_FNL's

# %%
# T only vs l3max

plt.figure(figsize=(9,5))

plt.yscale("linear")

#plt.xlim(1e3,1e5)

plt.plot(l3list, FisherInfo_T_30[:,-1,0,0]**-.5,label = r'$z=30$', color = 'royalblue', linewidth = 2, linestyle = '-', zorder = 10)
plt.plot(l3list, FisherInfo_T_50[:,-1,0,0]**-.5, label = r'$z=50$', color = 'darkorange', linewidth = 2, linestyle = '-', zorder = 10)
plt.plot(l3list, FisherInfo_T_100[:,-1,0,0]**-.5, label = r'$z=100$', color = 'darkgreen', linewidth = 2, linestyle = '-', zorder = 10)


plt.plot(l3list,1/snr30, color = 'royalblue', linewidth = 2, linestyle = '--', zorder = 10)
plt.plot(l3list,1/snr50, color = 'darkorange', linewidth = 2, linestyle = '--', zorder = 10)
plt.plot(l3list,1/snr100, color = 'darkgreen', linewidth = 2, linestyle = '--', zorder = 10)



plt.xlabel(r'$\ell_3^{\rm max}$', fontsize=25)
plt.ylabel(r'$\sigma(f_{\rm NL}^{\rm loc})$', fontsize=20)
plt.legend(loc='best',fontsize=18)#(loc='best', fontsize=20)

#plt.title(r'$T \, \,$ only', fontsize=20)


plt.tick_params(axis='both', which='both', direction='in', top=True, right=True, labelsize=20)
plt.grid(True, which='both',linestyle='--', alpha = 0.4)

# plt.ylim([1e-13,7e1])

# ax1.set_ylim([1.4e-6,6.2e-6])
plt.savefig("plots/squeez_DeltafNLvsl3.pdf", dpi=300, bbox_inches='tight')
plt.show()

# %%
# T only vs l1max

plt.figure(figsize=(9,5))

plt.xscale("log")
plt.yscale("log")


#plt.xlim(1e3,1e5)

plt.plot(llist2, FisherInfo_T_30[-1,:,0,0]**-.5, label = r'$z=30$', color = 'royalblue', linewidth = 2, linestyle = '-', zorder = 10)
plt.plot(llist2, FisherInfo_T_50[-1,:,0,0]**-.5, label = r'$z=50$', color = 'darkorange', linewidth = 2, linestyle = '-', zorder = 10)
plt.plot(llist2, FisherInfo_T_100[-1,:,0,0]**-.5, label = r'$z=100$', color = 'darkgreen', linewidth = 2, linestyle = '-', zorder = 10)


plt.xlabel(r'$\ell_1^{\rm max}$', fontsize=25)
#plt.ylabel(r'$\sigma(f_{\rm NL}^{\rm loc})$', fontsize=20)
#plt.legend(bbox_to_anchor=(1.20, 0.65), loc='center', ncol = 1, borderaxespad=0., fontsize=18)#(loc='best', fontsize=20)

#plt.title(r'$T \, \,$ only', fontsize=20)

plt.tick_params(axis='both', which='both', direction='in', top=True, right=True, labelsize=20)
plt.grid(True, which='both',linestyle='--', alpha = 0.4)

# plt.ylim([1e-13,7e1])

# ax1.set_ylim([1.4e-6,6.2e-6])
plt.savefig("plots/squeez_DeltafNLvsl1.pdf", dpi=300, bbox_inches='tight')
plt.show()

# %%
# T+E vs l3max

plt.figure(figsize=(9,5))

plt.yscale("linear")

#plt.xlim(1e3,1e5)

plt.plot(l3list, FisherInfo_TE_30[:,-1,0,0]**-.5,label = r'$z=30$', color = 'royalblue', linewidth = 2, linestyle = '-', zorder = 10)
plt.plot(l3list, FisherInfo_TE_50[:,-1,0,0]**-.5, label = r'$z=50$', color = 'darkorange', linewidth = 2, linestyle = '-', zorder = 10)
plt.plot(l3list, FisherInfo_TE_100[:,-1,0,0]**-.5, label = r'$z=100$', color = 'darkgreen', linewidth = 2, linestyle = '-', zorder = 10)


plt.xlabel(r'$\ell_3^{\rm max}$', fontsize=25)
plt.ylabel(r'$\sigma(f_{\rm NL}^{\rm loc})$', fontsize=20)
plt.legend(loc='best', fontsize=18)#(loc='best', fontsize=20)

#plt.title(r'$T+E$', fontsize=20)


plt.tick_params(axis='both', which='both', direction='in', top=True, right=True, labelsize=20)
plt.grid(True, which='both',linestyle='--', alpha = 0.4)

# plt.ylim([1e-13,7e1])

# ax1.set_ylim([1.4e-6,6.2e-6])
plt.savefig("plots/squeez_DeltafNLvsl3TpE.pdf", dpi=300, bbox_inches='tight')
plt.show()

# %%
# T+E vs l1max

plt.figure(figsize=(9,5))

plt.xscale("log")
plt.yscale("log")


#plt.xlim(1e3,1e5)

plt.plot(llist2, FisherInfo_TE_30[-1,:,0,0]**-.5, label = r'$z=30$', color = 'royalblue', linewidth = 2, linestyle = '-', zorder = 10)
plt.plot(llist2, FisherInfo_TE_50[-1,:,0,0]**-.5, label = r'$z=50$', color = 'darkorange', linewidth = 2, linestyle = '-', zorder = 10)
plt.plot(llist2, FisherInfo_TE_100[-1,:,0,0]**-.5, label = r'$z=100$', color = 'darkgreen', linewidth = 2, linestyle = '-', zorder = 10)


plt.xlabel(r'$\ell_1^{\rm max}$', fontsize=25)
#plt.ylabel(r'$\sigma(f_{\rm NL}^{\rm loc})$', fontsize=20)
#plt.legend(bbox_to_anchor=(1.20, 0.65), loc='center', ncol = 1, borderaxespad=0., fontsize=18)#(loc='best', fontsize=20)

#plt.title(r'$T \, \,$ only', fontsize=20)

plt.tick_params(axis='both', which='both', direction='in', top=True, right=True, labelsize=20)
plt.grid(True, which='both',linestyle='--', alpha = 0.4)

# plt.ylim([1e-13,7e1])

# ax1.set_ylim([1.4e-6,6.2e-6])
plt.savefig("plots/squeez_DeltafNLvsl1TpE.pdf", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # BIAS TO F_NL^LOC MEASURE

# %%
# Plot of bias vs l3max, 1-% residuals

fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))
                        

ax1.set_title(r'$T$ only', fontsize=18)
ax2.set_title(r'$T+E$', fontsize=18)


ax1.set_xlabel(r'$\ell^{\rm max}_3$', fontsize=18)
ax2.set_xlabel(r'$\ell^{\rm max}_3$', fontsize=18)


ax1.set_xlim(1,12)
ax2.set_xlim(1,12)


ax1.set_ylabel(r'$\Delta_b f_{\rm NL}^{\rm loc}$', fontsize=18)


ax1.set_yscale('log')
ax2.set_yscale('log')



ax1.plot(l3list,(.01*FisherInfo_T_30[:,-1,0,1]*I1c(30)+.01*FisherInfo_T_30[:,-1,0,2]*I2c(30))/FisherInfo_T_30[:,-1,0,0], label = r'$z=30$', color = 'royalblue', linewidth = 2, linestyle = '-', zorder = 10)
ax1.plot(l3list,(.01*FisherInfo_T_50[:,-1,0,1]*I1c(50)+.01*FisherInfo_T_50[:,-1,2,2]*I2c(50))/FisherInfo_T_50[:,-1,0,0], label = r'$z=50$', color = 'darkorange', linewidth = 2, linestyle = '-', zorder = 10)
ax1.plot(l3list,(.01*FisherInfo_T_100[:,-1,0,1]*I1c(100)+.01*FisherInfo_T_100[:,-1,0,2]*I2c(100))/FisherInfo_T_100[:,-1,0,0], label = r'$z=100$', color = 'darkgreen', linewidth = 2, linestyle = '-', zorder = 10)


ax1.plot(l3list,(.01*FisherInfo_T_30[:,-1,0,1]*I1c(30))/FisherInfo_T_30[:,-1,0,0], color = 'royalblue', linewidth = 2, linestyle = '--', zorder = 10)
ax1.plot(l3list,(.01*FisherInfo_T_50[:,-1,0,1]*I1c(50))/FisherInfo_T_50[:,-1,0,0], color = 'darkorange', linewidth = 2, linestyle = '--', zorder = 10)
ax1.plot(l3list,(.01*FisherInfo_T_100[:,-1,0,1]*I1c(100))/FisherInfo_T_100[:,-1,0,0], color = 'darkgreen', linewidth = 2, linestyle = '--', zorder = 10)



ax2.plot(l3list,.01*(FisherInfo_TE_30[:,-1,0,1]*I1c(30)+FisherInfo_TE_30[:,-1,0,2]*I2c(30))/FisherInfo_TE_30[:,-1,0,0], label = r'$z=30$', color = 'royalblue', linewidth = 2, linestyle = '-', zorder = 10)
ax2.plot(l3list,.01*(FisherInfo_TE_50[:,-1,0,1]*I1c(50)+FisherInfo_TE_50[:,-1,2,2]*I2c(50))/FisherInfo_TE_50[:,-1,0,0], label = r'$z=50$', color = 'darkorange', linewidth = 2, linestyle = '-', zorder = 10)
ax2.plot(l3list,.01*(FisherInfo_TE_100[:,-1,0,1]*I1c(100)+FisherInfo_TE_100[:,-1,0,2]*I2c(100))/FisherInfo_TE_100[:,-1,0,0], label = r'$z=100$', color = 'darkgreen', linewidth = 2, linestyle = '-', zorder = 10)


ax2.plot(l3list,(.01*FisherInfo_TE_30[:,-1,0,1]*I1c(30))/FisherInfo_TE_30[:,-1,0,0], color = 'royalblue', linewidth = 2, linestyle = '--', zorder = 10)
ax2.plot(l3list,(.01*FisherInfo_TE_50[:,-1,0,1]*I1c(50))/FisherInfo_TE_50[:,-1,0,0], color = 'darkorange', linewidth = 2, linestyle = '--', zorder = 10)
ax2.plot(l3list,(.01*FisherInfo_TE_100[:,-1,0,1]*I1c(100))/FisherInfo_TE_100[:,-1,0,0], color = 'darkgreen', linewidth = 2, linestyle = '--', zorder = 10)


ax2.legend(bbox_to_anchor=(1.20, 0.85), loc='center', ncol = 1, borderaxespad=0., fontsize=18)#(loc='best', fontsize=20)


ax1.tick_params(axis='both', which='both', direction='in', top=True, right=True, labelsize=20)
ax1.grid(True, which='both',linestyle='--', alpha = 0.4)

ax2.tick_params(axis='both', which='both', direction='in', top=True, right=True, labelsize=20)
ax2.grid(True, which='both',linestyle='--', alpha = 0.4)

# plt.ylim([1e-13,7e1])

# ax1.set_ylim([1.4e-6,6.2e-6])
plt.savefig("plots/biasfNLvsl3.pdf", dpi=300, bbox_inches='tight')
plt.show()

# %%
# Need this to invert the covariance matrix

FisherInfo_T_30[:,-1][0,2,2]= 1e-20
FisherInfo_T_40[:,-1][0,2,2]= 1e-20
FisherInfo_T_50[:,-1][0,2,2]= 1e-20
FisherInfo_T_60[:,-1][0,2,2]= 1e-20
FisherInfo_T_80[:,-1][0,2,2]= 1e-20
FisherInfo_T_100[:,-1][0,2,2]= 1e-20


FisherInfo_TE_30[:,-1][0,2,2]= 1e-20
FisherInfo_TE_40[:,-1][0,2,2]= 1e-20
FisherInfo_TE_50[:,-1][0,2,2]= 1e-20
FisherInfo_TE_60[:,-1][0,2,2]= 1e-20
FisherInfo_TE_80[:,-1][0,2,2]= 1e-20
FisherInfo_TE_100[:,-1][0,2,2]= 1e-20

# %%
# Need this to compute bias

FisherInfo_T_30_b= np.copy(FisherInfo_T_30)
FisherInfo_T_40_b= np.copy(FisherInfo_T_40)
FisherInfo_T_50_b= np.copy(FisherInfo_T_50)
FisherInfo_T_60_b= np.copy(FisherInfo_T_60)
FisherInfo_T_80_b= np.copy(FisherInfo_T_80)
FisherInfo_T_100_b= np.copy(FisherInfo_T_100)



FisherInfo_TE_30_b= np.copy(FisherInfo_TE_30)
FisherInfo_TE_40_b= np.copy(FisherInfo_TE_40)
FisherInfo_TE_50_b= np.copy(FisherInfo_TE_50)
FisherInfo_TE_60_b= np.copy(FisherInfo_TE_60)
FisherInfo_TE_80_b= np.copy(FisherInfo_TE_80)
FisherInfo_TE_100_b= np.copy(FisherInfo_TE_100)

# %%
# Need this to compute bias

FisherInfo_T_30_b[:,-1][:,0,1]= FisherInfo_T_30_b[:,-1][:,0,1]*I1c(30)
FisherInfo_T_40_b[:,-1][:,0,1]= FisherInfo_T_40_b[:,-1][:,0,1]*I1c(40)
FisherInfo_T_50_b[:,-1][:,0,1]= FisherInfo_T_50_b[:,-1][:,0,1]*I1c(50)
FisherInfo_T_60_b[:,-1][:,0,1]= FisherInfo_T_60_b[:,-1][:,0,1]*I1c(60)
FisherInfo_T_80_b[:,-1][:,0,1]= FisherInfo_T_80_b[:,-1][:,0,1]*I1c(80)
FisherInfo_T_100_b[:,-1][:,0,1]= FisherInfo_T_100_b[:,-1][:,0,1]*I1c(100)



FisherInfo_T_30_b[:,-1][:,0,2]= FisherInfo_T_30_b[:,-1][:,0,2]*I2c(30)
FisherInfo_T_40_b[:,-1][:,0,2]= FisherInfo_T_40_b[:,-1][:,0,2]*I2c(40)
FisherInfo_T_50_b[:,-1][:,0,2]= FisherInfo_T_50_b[:,-1][:,0,2]*I2c(50)
FisherInfo_T_60_b[:,-1][:,0,2]= FisherInfo_T_60_b[:,-1][:,0,2]*I2c(60)
FisherInfo_T_80_b[:,-1][:,0,2]= FisherInfo_T_80_b[:,-1][:,0,2]*I2c(80)
FisherInfo_T_100_b[:,-1][:,0,2]= FisherInfo_T_100_b[:,-1][:,0,2]*I2c(100)



FisherInfo_TE_30_b[:,-1][:,0,1]= FisherInfo_TE_30_b[:,-1][:,0,1]*I1c(30)
FisherInfo_TE_40_b[:,-1][:,0,1]= FisherInfo_TE_40_b[:,-1][:,0,1]*I1c(40)
FisherInfo_TE_50_b[:,-1][:,0,1]= FisherInfo_TE_50_b[:,-1][:,0,1]*I1c(50)
FisherInfo_TE_60_b[:,-1][:,0,1]= FisherInfo_TE_60_b[:,-1][:,0,1]*I1c(60)
FisherInfo_TE_80_b[:,-1][:,0,1]= FisherInfo_TE_80_b[:,-1][:,0,1]*I1c(80)
FisherInfo_TE_100_b[:,-1][:,0,1]= FisherInfo_TE_100_b[:,-1][:,0,1]*I1c(100)



FisherInfo_TE_30_b[:,-1][:,0,2]= FisherInfo_TE_30_b[:,-1][:,0,2]*I2c(30)
FisherInfo_TE_40_b[:,-1][:,0,2]= FisherInfo_TE_40_b[:,-1][:,0,2]*I2c(40)
FisherInfo_TE_50_b[:,-1][:,0,2]= FisherInfo_TE_50_b[:,-1][:,0,2]*I2c(50)
FisherInfo_TE_60_b[:,-1][:,0,2]= FisherInfo_TE_60_b[:,-1][:,0,2]*I2c(60)
FisherInfo_TE_80_b[:,-1][:,0,2]= FisherInfo_TE_80_b[:,-1][:,0,2]*I2c(80)
FisherInfo_TE_100_b[:,-1][:,0,2]= FisherInfo_TE_100_b[:,-1][:,0,2]*I2c(100)

# %%
# Plot of marginalized deltafNL vs l3max

fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))

fig.subplots_adjust(wspace=0.2)

ax1.set_title(r'$T$ only', fontsize=18)
ax2.set_title(r'$T+E$', fontsize=18)


ax1.set_xlabel(r'$\ell^{\rm max}_3$', fontsize=18)
ax2.set_xlabel(r'$\ell^{\rm max}_3$', fontsize=18)


ax1.set_xlim(5.5,11.5)
ax2.set_xlim(5.5,11.5)


ax1.set_ylabel(r'$\sigma(f_{\rm NL}^{\rm loc})$', fontsize=18)


ax1.set_yscale('linear')
ax2.set_yscale('linear')


ax1.plot(l3list,np.linalg.inv(FisherInfo_T_30[:,-1])[:,0,0]**.5, label = r'$z=30$', color = 'royalblue', linewidth = 2, linestyle = '-', zorder = 10)
ax1.plot(l3list,np.linalg.inv(FisherInfo_T_50[:,-1])[:,0,0]**.5, label = r'$z=50$', color = 'darkorange', linewidth = 2, linestyle = '-', zorder = 10)
ax1.plot(l3list,np.linalg.inv(FisherInfo_T_100[:,-1])[:,0,0]**.5, label = r'$z=100$', color = 'darkgreen', linewidth = 2, linestyle = '-', zorder = 10)


ax2.plot(l3list,np.linalg.inv(FisherInfo_TE_30[:,-1])[:,0,0]**.5, label = r'$z=30$', color = 'royalblue', linewidth = 2, linestyle = '-', zorder = 10)
ax2.plot(l3list,np.linalg.inv(FisherInfo_TE_50[:,-1])[:,0,0]**.5, label = r'$z=50$', color = 'darkorange', linewidth = 2, linestyle = '-', zorder = 10)
ax2.plot(l3list,np.linalg.inv(FisherInfo_TE_100[:,-1])[:,0,0]**.5, label = r'$z=100$', color = 'darkgreen', linewidth = 2, linestyle = '-', zorder = 10)

ax2.legend(loc='best', fontsize=20)


ax1.tick_params(axis='both', which='both', direction='in', top=True, right=True, labelsize=20)
ax1.grid(True, which='both',linestyle='--', alpha = 0.4)

ax2.tick_params(axis='both', which='both', direction='in', top=True, right=True, labelsize=20)
ax2.grid(True, which='both',linestyle='--', alpha = 0.4)

# plt.ylim([1e-13,7e1])

ax1.set_ylim(0.1,0.6)
ax2.set_ylim(0.1,0.3)

# ax1.set_ylim([1.4e-6,6.2e-6])
plt.savefig("plots/sigmafnl_margin.pdf", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /global/homes/g/gorlando/.conda/envs/myenv/lib/python3.7/site-packages/ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in sqrt

# %%
fishintT = interp1d([30,40,50,60,80,100],np.array([FisherInfo_T_30,FisherInfo_T_40,FisherInfo_T_50,FisherInfo_T_60,FisherInfo_T_80,FisherInfo_T_100])[:,:,-1],axis=0)
fishintTpE = interp1d([30,40,50,60,80,100],np.array([FisherInfo_TE_30,FisherInfo_TE_40,FisherInfo_TE_50,FisherInfo_TE_60,FisherInfo_TE_80,FisherInfo_TE_100])[:,:,-1],axis=0)


fishintT_b = interp1d([30,40,50,60,80,100],np.array([FisherInfo_T_30_b,FisherInfo_T_40_b,FisherInfo_T_50_b,FisherInfo_T_60_b,FisherInfo_T_80_b,FisherInfo_T_100_b])[:,:,-1],axis=0)
fishintTpE_b = interp1d([30,40,50,60,80,100],np.array([FisherInfo_TE_30_b,FisherInfo_TE_40_b,FisherInfo_TE_50_b,FisherInfo_TE_60_b,FisherInfo_TE_80_b,FisherInfo_TE_100_b])[:,:,-1],axis=0)

# %%
zlistplt = np.linspace(30,100,300)

# %%
# Plot of deltafNL vs l3max, tomography with bias 


plt.figure(figsize=(9,5))

plt.yscale("log")

#plt.xlim(1e3,1e5)

plt.plot(l3list, fishintT(zlistplt).sum(0)[:,0,0]**-.5,label = r'$T$', color = 'black', linewidth = 2, linestyle = '-', zorder = 10)
plt.plot(l3list, fishintTpE(zlistplt).sum(0)[:,0,0]**-.5, label = r'$T+E$', color = 'red', linewidth = 2, linestyle = '-', zorder = 10)


plt.plot(l3list, np.linalg.inv((fishintT(zlistplt).sum(0))[:,:])[:,0,0]**.5, color = 'black', linewidth = 2, linestyle = '--', zorder = 10)
plt.plot(l3list, np.linalg.inv((fishintTpE(zlistplt).sum(0))[:,:])[:,0,0]**.5, color = 'red', linewidth = 2, linestyle = '--', zorder = 10)

plt.plot(l3list, .01*(fishintT_b(zlistplt).sum(0)[:,0,1]+fishintT_b(zlistplt).sum(0)[:,0,2])/(fishintT(zlistplt).sum(0)[:,0,0]), color = 'black', linewidth = 2, linestyle = '-.', zorder = 10)
plt.plot(l3list, .01*(fishintTpE_b(zlistplt).sum(0)[:,0,1]+fishintTpE_b(zlistplt).sum(0)[:,0,2])/(fishintTpE(zlistplt).sum(0)[:,0,0]), color = 'red', linewidth = 2, linestyle = '-.', zorder = 10)

plt.xlabel(r'$\ell_3^{\rm max}$', fontsize=25)
plt.ylabel(r'$\sigma(f_{\rm NL}^{\rm loc})$', fontsize=20)
plt.legend(bbox_to_anchor=(1.15, 0.85), loc='center', ncol = 1, borderaxespad=0., fontsize=18)#(loc='best', fontsize=20)

plt.title(r'tomography $N_z = 300$', fontsize=20)


plt.tick_params(axis='both', which='both', direction='in', top=True, right=True, labelsize=20)
plt.grid(True, which='both',linestyle='--', alpha = 0.4)

# plt.ylim([1e-13,7e1])

# ax1.set_ylim([1.4e-6,6.2e-6])
plt.savefig("plots/squeez_DeltafNLvsl3_tom.pdf", dpi=300, bbox_inches='tight')
plt.show()

# %%
# END OF TRACK
